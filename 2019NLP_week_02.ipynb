# %%
# !pwd
# Out:
# /Users/wy/Desktop/python32期开班环境（必装）/3_种子软件（必装）/study/2019NLP

# %%
database = '/Users/wy/Desktop/datasource/sqlResult_1558435.csv'

# %%
import os

# %%
os.path.exists(database)
# Out:
# True

# %%
import pandas as pd

# %%
dataframe = pd.read_csv(database,encoding='gb18030')

# %%
dataframe
# Out:
#           id            author                    source  \
# 0      89617               NaN    快科技@http://www.kkj.cn/
# 1      89616               NaN    快科技@http://www.kkj.cn/
# 2      89615               NaN    快科技@http://www.kkj.cn/
# 3      89614               NaN                       新华社
# 4      89613        胡淑丽_MN7479                     深圳大件事
# 5      89612                张怡                 中国证券报?中证网
# 6      89611               NaN  威锋网@http://www.feng.com/
# 7      89610            申玉彬 整理                 中国证券报?中证网
# 8      89609        李杭_BJS4645                 荆楚网-楚天都市报
# 9      89608                吴瞬                 中国证券报?中证网
# 10     89607               NaN                     证券时报网
# 11     89606               NaN                     证券时报网
# 12     89605               NaN                     中国新闻网
# 13     89604            申玉彬 整理                 中国证券报?中证网
# 14     89603               NaN                      国际在线
# 15     89602               费天元                     中国证券网
# 16     89601               NaN                  solidot@
# 17     89600               NaN                       新华网
# 18     89599                张怡                 中国证券报?中证网
# 19     89598             周佳 整理                 中国证券报?中证网
# 20     89597               NaN                       泡泡网
# 21     89596             周佳 整理                 中国证券报?中证网
# 22     89595               NaN  威锋网@http://www.feng.com/
# 23     89594                张怡                 中国证券报?中证网
# 24     89593         屠震林 PS040                      凤凰体育
# 25     89592               NaN                       新华网
# 26     89591               NaN                      雷锋网@
# 27     89590               NaN                       新华网
# 28     89589               NaN                      中超球评
# 29     89588               NaN                    中国经济周刊
# ...      ...               ...                       ...
# 89581     30       INACIO ROSA                       新华社
# 89582     29       INACIO ROSA                       新华社
# 89583     28       INACIO ROSA                       新华社
# 89584     27       INACIO ROSA                       新华社
# 89585     26       INACIO ROSA                       新华社
# 89586     25       INACIO ROSA                       新华社
# 89587     24      LOVELY GHOSH                       新华社
# 89588     23      LOVELY GHOSH                       新华社
# 89589     22      LOVELY GHOSH                       新华社
# 89590     21      LOVELY GHOSH                       新华社
# 89591     20      LOVELY GHOSH                       新华社
# 89592     19                张旌                       新华社
# 89593     18               NaN                       新华社
# 89594     17  LISELOTTE SABROE                       新华社
# 89595     16  LISELOTTE SABROE                       新华社
# 89596     15  LISELOTTE SABROE                       新华社
# 89597     14  LISELOTTE SABROE                       新华社
# 89598     13  LISELOTTE SABROE                       新华社
# 89599     12  LISELOTTE SABROE                       新华社
# 89600     11  LISELOTTE SABROE                       新华社
# 89601     10  LISELOTTE SABROE                       新华社
# 89602      9  LISELOTTE SABROE                       新华社
# 89603      8               郑焕松                       新华社
# 89604      7               郑焕松                       新华社
# 89605      6               郑焕松                       新华社
# 89606      5                邹峥                       新华社
# 89607      4                王衡                       新华社
# 89608      3                张旌                       新华社
# 89609      2               夏文辉                       新华社
# 89610      1            王子江 张寒                       新华社
#
#                                                  content  \
# 0      此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 89607  新华社兰州6月3日电（王衡、徐丹）记者从甘肃省交通运输厅获悉，甘肃近日集中开建高速公路、普通...
# 89608  \n\n2017年5月29日，在法国巴黎郊外的凡尔赛宫，法国总统马克龙出席新闻发布会。（新华...
# 89609  \n\n2017年5月25日，在美国马萨诸塞州剑桥市，哈佛大学毕业生在毕业典礼上欢呼。（新华...
# 89610  　　新华社德国杜塞尔多夫６月６日电题：乒乓女球迷　\n　　新华社记者王子江、张寒\n　　熊老...
#
#                                                  feature  \
# 0      {"type":"科技","site":"cnbeta","commentNum":"37"...
# 1      {"type":"科技","site":"cnbeta","commentNum":"15"...
# 2      {"type":"科技","site":"cnbeta","commentNum":"18"...
# 3      {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 4      {"type":"新闻","site":"网易热门","commentNum":"978",...
# 5      {"type":"市场","site":"中证网","commentNum":"0","jo...
# 6      {"type":"科技","site":"cnbeta","commentNum":"21"...
# 7      {"type":"市场","site":"中证网","commentNum":"0","jo...
# 8      {"type":"新闻","site":"网易热门","commentNum":"1600"...
# 9      {"type":"市场","site":"中证网","commentNum":"0","jo...
# 10     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 11     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 12     {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 13     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 14     {"type":"观点滚动","site":"参考消息","commentNum":"0",...
# 15     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 16     {"type":"软件","site":"cnbeta","commentNum":"12"...
# 17     {"type":"观点滚动","site":"参考消息","commentNum":"0",...
# 18     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 19     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 20     {"type":"军事","site":"新浪","commentNum":" 95","j...
# 21     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 22     {"type":"科技","site":"cnbeta","commentNum":"56"...
# 23     {"type":"市场","site":"中证网","commentNum":"0","jo...
# 24     {"type":"体育","site":"凤凰","commentNum":"1","joi...
# 25     {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 26     {"type":"科技","site":"cnbeta","commentNum":"4",...
# 27     {"type":"国际新闻","site":"环球","commentNum":"0","j...
# 28     {"type":"体育","site":"凤凰","commentNum":"0","joi...
# 29     {"type":"科技","site":"新浪","commentNum":" 6","jo...
# ...                                                  ...
# 89581  {"type":"足球","site":"新华社","url":"http://home.x...
# 89582  {"type":"足球","site":"新华社","url":"http://home.x...
# 89583  {"type":"足球","site":"新华社","url":"http://home.x...
# 89584  {"type":"足球","site":"新华社","url":"http://home.x...
# 89585  {"type":"足球","site":"新华社","url":"http://home.x...
# 89586  {"type":"足球","site":"新华社","url":"http://home.x...
# 89587  {"type":"其它","site":"新华社","url":"http://home.x...
# 89588  {"type":"其它","site":"新华社","url":"http://home.x...
# 89589  {"type":"其它","site":"新华社","url":"http://home.x...
# 89590  {"type":"其它","site":"新华社","url":"http://home.x...
# 89591  {"type":"其它","site":"新华社","url":"http://home.x...
# 89592  {"type":"其它","site":"新华社","url":"http://home.x...
# 89593  {"type":"其它","site":"新华社","url":"http://home.x...
# 89594  {"type":"足球","site":"新华社","url":"http://home.x...
# 89595  {"type":"足球","site":"新华社","url":"http://home.x...
# 89596  {"type":"足球","site":"新华社","url":"http://home.x...
# 89597  {"type":"足球","site":"新华社","url":"http://home.x...
# 89598  {"type":"足球","site":"新华社","url":"http://home.x...
# 89599  {"type":"足球","site":"新华社","url":"http://home.x...
# 89600  {"type":"足球","site":"新华社","url":"http://home.x...
# 89601  {"type":"足球","site":"新华社","url":"http://home.x...
# 89602  {"type":"足球","site":"新华社","url":"http://home.x...
# 89603  {"type":"社会","site":"新华社","url":"http://home.x...
# 89604  {"type":"社会","site":"新华社","url":"http://home.x...
# 89605  {"type":"社会","site":"新华社","url":"http://home.x...
# 89606  {"type":"冰球","site":"新华社","url":"http://home.x...
# 89607  {"type":"宏观经济","site":"新华社","url":"http://home...
# 89608  {"type":"其它","site":"新华社","url":"http://home.x...
# 89609  {"type":"其它","site":"新华社","url":"http://home.x...
# 89610  {"type":"体育","site":"新华社","url":"http://home.x...
#
#                                title  \
# 0               小米MIUI 9首批机型曝光：共计15款
# 1         骁龙835在Windows 10上的性能表现有望改善
# 2          一加手机5细节曝光：3300mAh、充半小时用1天
# 3      葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4           44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
# 5                     金融股一枝独秀 配置价值犹存
# 6                配骁龙660 全面屏鼻祖夏普新机酝酿中
# 7                    博友早评：震荡有利消化套牢筹码
# 8           武汉千余警察出动 抓获808名俊男靓女全是诈骗犯
# 9                纳入MSCI指数 A股长期配置价值提升
# 10              私募：蓝筹风格难切换 业绩估值相配是王道
# 11            早间机构看市：市场将再次探底 两类股逢低布局
# 12           因为犯罪现场的一根头发，他坐冤狱41年后终获释
# 13                     博友午评：风格转换前的阵痛
# 14              MSCI闯关成功会是A股的一针强心剂吗？
# 15            地产股拉升难阻市场颓势 三大指数早盘集体跳水
# 16               Debian 9 Stretch 发布
# 17                 [及时点]我们不需要“百变老太太”
# 18                新三板午评：三板做市指数刷新阶段低点
# 19              机构解析：下周热点板块及个股探秘（附股）
# 20           美军击落叙战机激怒俄罗斯 俄警告将瞄准美军战机
# 21                   机构推荐：下周具备布局潜力金股
# 22              业内人士解释为什么OPPO供货能力强无敌
# 23                中证午评：A股跳水 蓝筹暂歇热点熄火
# 24         “齐心协力”--江苏苏宁发布足协杯对阵河南建业海报
# 25       土耳其近590名士兵疑食物中毒 被送往医院救治（组图）
# 26          又一自动驾驶公司拿加州路测牌照 这回是王劲的景驰
# 27         火灾与脱欧炙烤英国首相 特雷莎·梅面临空前政治压力
# 28           江苏保级真悬了 近3年1铁律证明其几乎保级无望
# 29            乐视危局：靠卖资产续命 员工被猎头大规模拉黑
# ...                              ...
# 89581         [2]（外代二线）足球——世预赛：葡萄牙备战
# 89582         [3]（外代二线）足球——世预赛：葡萄牙备战
# 89583         [4]（外代二线）足球——世预赛：葡萄牙备战
#  '骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考虑性能而去屏蔽掉小核心。相反，他们正联手微软，找到一种适合桌面平台的、兼顾性能和功耗的完美方案。\r\n报道称，微软已经拿到了一些新的源码，以便Windows 10更好地理解big.little架构。\r\n资料显示，骁龙835作为一款集成了CPU、GPU、基带、蓝牙/Wi-Fi的SoC，比传统的Wintel方案可以节省至少30%的PCB空间。\r\n按计划，今年Q4，华硕、惠普、联想将首发骁龙835 Win10电脑，预计均是二合一形态的产品。\r\n当然，高通骁龙只是个开始，未来也许还能见到三星Exynos、联发科、华为麒麟、小米澎湃等进入Windows 10桌面平台。\r\n',
#  '此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n至于电池缩水，可能与刘作虎所说，一加手机5要做市面最轻薄大屏旗舰的设定有关。\r\n按照目前掌握的资料，一加手机5拥有5.5寸1080P三星AMOLED显示屏、6G/8GB RAM，64GB/128GB ROM，双1600万摄像头，备货量“惊喜”。\r\n根据京东泄露的信息，一加5起售价是xx99元，应该是在2799/2899/2999中的某个。\r\n',
#  '这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n',
#  '（原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清晨交警发现有一女子赤裸上身，行走在南坪快速上，期间还起了轻生年头，一辅警发现后赶紧为其披上黄衣，并一路劝说她。\r\n那么事发时\r\n到底都发生了些什么呢？\r\n南都记者带您一起还原现场\r\n南都记者在龙岗大队坂田中队见到了辅警刘青（发现女生的辅警），一位外表高大帅气，说话略带些腼腆的90后青年。\r\n刘青介绍，6月16日早上7时36分，他正在环城南路附近值勤，接到中队关于一位女子裸身进入机动车可能有危险的警情，随后骑着小铁骑开始沿路寻找，大概花了十多分钟在南坪大道坂田出口往龙岗方向的逆行辅道上发现该女子。\r\n女子身上一丝不挂地逆车流而行，时走时停，时坐时躺，险象环生。刘青停好小铁骑，和另外一名巡防员追了上去，发现女子的情绪很低落，话不多，刘青尝试和女子交流，劝说女子离开，可女子并不愿意接受，继续缓慢地往南坪快速路的主干道上走去。\r\n此时路边上已经聚集了很市民围观，为了不刺激女子的情绪，刘青和巡防员一边盯着女子一边驱赶着围观的群众。\r\n现场还原\r\n从警方提供的一份视频了解到，16日早上7时25分，女子出现在坂雪岗大道与环城南路的监控视频中，此时女子还穿着白色的内裤，正沿着坂雪岗大道往南坪快速的方向缓慢地走着。\r\n当时正值上班高峰期，十字路口的车流已经排起了长队。当女子出现时，路上的市民纷纷驻足观望，不少车辆也放慢了速度，但女子并不为市民观望停下脚步，依然缓慢走着。当女子行进到十字路口中间时，一辆大货车挡住了镜头，但是当女子再次出现镜头时，可以发现女子已经没穿内裤了，全身裸露继续朝着南坪快速方向走去。记者发现，视频中女子周围并没有人尾随或者上前劝止的市民。\r\n一大清早路上看到这样的情况\r\n恐怕大家都没办法淡定\r\n面对这一情况\r\n刘青表示，“一开始根本不敢看她，心里挺别扭，感觉很尴尬”，但当刘青跟随女子上了南坪快速路主干道时，女子作出了让人意想不到的举动，她突然靠近护栏要从上面跳下去，刘青赶忙冲上去拉住了女子的手，将其控制住并远离护栏。碍于女子没有穿衣服，刘青递上
均超过2%。相对而言，券商股多小幅下跌。\r\n\u3000\u3000近期，对A股市场消息面影响最大的就是MSCI宣布从2018年6月开始将A股纳入MSCI新兴市场指数。而其中，金融股是占比最大的一个群体。国金证券李立峰团队指出，最新方案中包含的222只成分股中，剔除了中等市值、非互联互通可交易的股票以及有停牌限制的标的，由于纳入了很多大市值AH股，A股在MSCI EM中的权重由0.5%上升到了0.73%。其中，金融板块占比最高，达到40.11%，泛消费次之，占比为24.26%，两个板块涵盖了大部分权重股。动态来看，由于加入了很多是指占比高的金融公司，金融板块的权重增加了近一半，其他大部分行业权重都受到了稀释。\r\n\u3000\u3000尽管A股被纳入MSCI这一利好事件对短期市场情绪有所提振、对中长期海外增量资金预期升温，但短期内，市场量能尚不能有效放大，金融股独乐乐情景也就难以持续。存量博弈格局下，风格交替、指数震荡格局难改变。\r\n\u3000\u3000光大证券指出，利好并未引起市场太大的热情，两市指数和成交量均较为平淡，但市场风格出现了较大变化，白马股金融股上涨的同时，成长股、题材股全天低迷。这表明市场增量资金依然很少，存量资金在不同板块之间腾挪，这样的跷跷板格局使得指数难有突破。市场中期依旧偏空，短期依旧可能维持震荡格局。\r\n',
#  '虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是今年 3 月份官方突然宣布回归中国，预示着很快就有夏普新机在中国登场了。那么，第一款夏普手机什么时候登陆中国呢？又会是怎么样的手机呢？\r\n近日，一款型号为 FS8016 的夏普神秘新机悄然出现在 GeekBench 的跑分库上。从其中相关信息了解到，这款机子并非旗舰定位，所搭载的是高通骁龙 660 处理器，配备有 4GB 的内存。骁龙 660 是高通今年最受瞩目的芯片之一，采用 14 纳米工艺，八个 Kryo 260 核心设计，集成 Adreno 512 GPU 和 X12 LTE 调制解调器。\r\n当前市面上只有一款机子采用了骁龙 660 处理器，那就是已经上市销售的 OPPO R11。骁龙 660 尽管并非旗舰芯片，但在多核新能上比去年骁龙 820 强，单核改进也很明显，所以放在今年仍可以让很多手机变成高端机。不过，由于 OPPO 与高通签署了排他性协议，可以独占两三个月时间。\r\n考虑到夏普既然开始测试新机了，说明只要等独占时期一过，夏普就能发布骁龙 660 新品了。按照之前被曝光的渲染图了解，夏普的新机核心竞争优势还是全面屏，因为从 2013 年推出全球首款全面屏手机 EDGEST 302SH 至今，夏普手机推出了多达 28 款的全面屏手机。\r\n在 5 月份的媒体沟通会上，惠普罗忠生表示：“我敢打赌，12 个月之后，在座的各位手机都会换掉。因为全面屏时代的到来，我们怀揣的手机都将成为传统手机。”\r\n',
#  '\u3000\u3000沙漠雄鹰：震荡有利消化套牢筹码\r\n\u3000\u3000周四开盘上证50在银行券商大蓝筹带动下一度涨近2%,沪指也一度站上60日与120日均线。但在“黑天鹅”万达电影暴跌拖累下,沪深股市绝大多数时间分道扬镳，14点后次新股大幅跳水令各大指数全线收绿。存量博弈格局难改,量能久日不见放大下,蓝筹行情并不可持续,短线策略依然是以题材为主，次新股和区域经济概念股调整压力仍然突出，成长股再次大跌，但目前处于底部，低位反复震荡有助于
，\r\n而给自己的生活抹上污点！\r\n俗话说，知己知彼百战不殆\r\n弄清网络诈骗的常见手法?\r\n才能避免上当受骗\r\n下面就为大家奉上防骗攻略\r\n遇到诈骗只需见招拆招！\r\n网络防骗攻略\r\n电信网络诈骗犯罪往往表现为“六大陷阱”：\r\n1.物美价廉的网购陷阱\r\n2.推销产品的便利陷阱\r\n3.异性交友的情感陷阱\r\n4.中奖信息的惊喜陷阱\r\n5.冒充国家工作人员的恐吓陷阱\r\n6.钓鱼网站和网上银行的迷惑陷阱\r\n下面是网络诈骗中比较常见的几种类型，一起学习如何防范，让骗子无处遁形！\r\n1虚假红包诈骗\r\n临近节日时，各大电商平台会以派发红包的形式，为促销活动预热。有不法分子趁机在微信朋友圈、微信群等平台中，派发虚假红包，诱骗大家点击，套取个人信息，或传播木马病毒，盗取银行账号。\r\n识骗方法：慎点此类红包领取链接，如果不小心点击，应第一时间关闭手机网络，修改网银、支付宝等重要账户密码，并通过安全软件查杀木马病毒。\r\n2二维码诈骗\r\n抢购高峰期，网页打开慢，网银交易出现比较迟钝现象。有不法分子会冒充客服或店主，以单子出现“调单”“卡单”等说法为幌子，故意说没有收到款项欺诈消费者，取得信任后要求消费者以其他办法进行转账。\r\n识骗方法：消费者要注意，调单、卡单、激活订单等多为诈骗术语，见此类词语基本可以断定对方是骗子。没有收到款项这样的问题，是不会在东京、天猫这样的大型网络购物平台出现的。\r\n3钓鱼网站诈骗\r\n节假日期间，公众的购物热情高涨，假冒正规电商官方网站、在线支付平台等的钓鱼网站活动频繁。消费者在忙于浏览各色商品页面时，往往容易忽略链接的安全性，从而误入诈骗分子发来的虚假钓鱼网站。\r\n识骗方法：对陌生人发来的商品链接要提高警惕，谨慎打开。如遇网络诈骗应第一时间向属地公安机关报案，并向举报中心举报。\r\n4虚假客服诈骗\r\n抢购高峰期，网页打开慢，网银交易出现比较迟钝现象。有不法分子会冒充客服或店主，以单子出现“调单”“卡单”等说法为幌子，故意说没有收到款项欺诈消费者，取得信任后要求消费者以其他办法进行转账。\r\n识骗方法：消费者要注意，调单、卡单、激活订单等多为诈骗术语，见此类词语基本可以断定对方是骗子。没有收到款项这样的问题，是不会在东京、天猫这样的大型网络购物平台出现的。\r\n5预购诈骗\r\n还有不法分子会以“提前购”、“预售”为诱饵向用户发送木马链接。除了网购链接被植入木马、钓鱼网站，还有不法分子会在“预售”活动上做文章，骗取买家“定金”。\r\n识骗方法：慎点不明链接，有关购物短信也不要轻信，同时也请给手机装上杀毒软件，提供安全的上网环境。\r\n6中奖诈骗\r\n购物过后，很多人会陆陆续续收到一些商家的中奖信息，切记不要随意拨打中奖信息提供的电话号码或点击发来的网站链接地址，很可能会让手机或电脑感染上木马病毒。\r\n识骗方法：收到中奖信息后留心一下，看一看你所购买的产品中有没有这家的产品，然后最好能在天猫店里直接和卖家联系确认消息。\r\n7朋友圈诈骗\r\n由于缺少第三方监管平台，不法分子会在朋友圈发布虚假低价购物信息，骗取消费者汇款购买。\r\n识骗方法：朋友圈里的销售行为，存在取证难，查处难的问题。因此建议大家在朋友圈买东西时，尽可能选择正规第三方支付平台进行支付，避免直接支付，以确保安全。\r\n8快递诈骗\r\n不法分子会从非法渠道获得客户信息，制作假的快递单，随后冒充快递员提前联系受骗者，把虚假货品送到消费者手中，骗取钱财。\r\n识骗方法：签收包裹前，务必按官方的信息核实对方身份，并确认是否是自己的包裹。在取货之后；一定记得把自己的个人信息从包裹上完全抹去；避免个人信息泄露。\r\n9退款诈骗\r\n不法分子常以“退款”或“退货”为由假扮网店客服，要求消费者点击其提供的“钓鱼网站”链接，盗取持卡人的银行密码及动态验证码。\r\n识骗方法：如果接到网上购物退款的电话或短信等信息，一定要谨慎对待，切莫泄露银行卡账号、户名，动态验证码等个人信息。\r\n同时，提醒大家：保护好自己账户信息，遇到情况一定及时报警。\r\n武汉破特大网络诈骗案抓808人:以"内幕消息"骗人\r\n6月12日，武汉市公安局向澎湃新闻通报，该局破获一起特大网络诈骗案。抓获包括卢某、熊某等8名首脑分子在内的涉案人员808名，查扣涉案电脑800余台、手机2000余部、银行卡3000余张。据悉，这是全国打击利用非法互联网金融平台实施诈骗犯罪中，查获涉案人数最多的一起案件。\r\n',
#  '\u3000\u30006月21日，A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22日，在222只纳入MSCI指数的A股股票中，银行股全线飘红，其中招商银行领涨，涨幅达6.66%。保险股和券商股的表现也可圈可点。在这222只股票中，金融板块的股票数量和总市值占比均位居首位。分析人士指出，银行股股息率高、估值低、收益稳定，对于资金量较大、投资期限较长的资金存在相当大的吸引力。从国际经验来看，纳入MSCI指数后，相关股市的投资者风格将更加稳健，更加偏好业绩稳定、流动性好、风险低的优质蓝筹股。\r\n\u3000\u3000银行股具估值优势\r\n\u3000\u30006月22日，A股金融股表现强势，板块涨幅达1.19%。据平安证券统计，在222只纳入MSCI指数的A股股票中，金融板块市值占比达41.32%，其中银行、证券和保险子板块的市值占比分别为27.30%、7.75%和6.24%。\r\n\u3000\u3000多家券商研究报告认为，银行等金融股受到纳入MSCI指数的提振，未来更多境外资金将进入金融股。\r\n\u3000\u3000华泰证券表示，在纳入MSCI指数之后，A股将迎来约850亿元人民币的增量资金。其中，考虑到222只股票中，金融股市值占比约42%，并且金融股体量大、流动性强、估值低，符合境外资金偏好，有望迎来超过权重的资金比例。预计金融股有望吸引增量资金约350亿元人民币。\r\n\u3000\u3000新富资本证券投资中心研究总监廖云龙认为，银行股脱颖而出的主要原因是低估值。市场预期银行股基本面改善，同时市场整体风格偏保守，偏爱低估值。22日银行股的大涨是市场风格的延续，是投资者对龙头股和对低估值的防御性选择。\r\n\u3000\u3000东方财富choice统计的一季度末QFII重仓股数据显示，银行股是QFII关注的重点之一。在前五十大重仓股中，北京银行、南京银行、宁波银行、上海银行榜上有名。\r\n']

# %%
import re

# %%
def token(string):
    return ' '.join(re.findall('[\w|\d+]',string))

# %%
string = 'this is a BIGGGGG,BBIGGGG'

# %%
pattern = '\w+'

# %%
re.findall(pattern,string)
# Out:
# ['this', 'is', 'a', 'BIGGGGG', 'BBIGGGG']

# %%
import requests
import re

# %%
url = 'https://movie.douban.com/'

# %%
response = requests.get(url)

# %%
url_pattern = re.compile('https://movie.douban.com/subject/\d+/\?from=showing')

# %%
image_pattern = re.compile('https://img3.doubanio.com/view/photo/s_ratio_poster/public/\w\d+.\w+')

# %%
html_content = response.text

# %%
original_string = 'href="https://movie.douban.com/subject/2244426/?from=showing"'

# %%
import matplotlib.pyplot as plt

# %%
a = plt.imread('2.PNG')

# %%
plt.imshow(a)
plt.show()

# %%
image_list = image_pattern.findall(html_content)

# %%
set(url_pattern.findall(html_content))
# Out:
# {'https://movie.douban.com/subject/1652592/?from=showing',
#  'https://movie.douban.com/subject/19899707/?from=showing',
#  'https://movie.douban.com/subject/2244426/?from=showing',
#  'https://movie.douban.com/subject/25833233/?from=showing',
#  'https://movie.douban.com/subject/25924056/?from=showing',
#  'https://movie.douban.com/subject/26266893/?from=showing',
#  'https://movie.douban.com/subject/26662282/?from=showing',
#  'https://movie.douban.com/subject/26715636/?from=showing',
#  'https://movie.douban.com/subject/26728669/?from=showing',
#  'https://movie.douban.com/subject/26774017/?from=showing',
#  'https://movie.douban.com/subject/26803717/?from=showing',
#  'https://movie.douban.com/subject/26850330/?from=showing',
#  'https://movie.douban.com/subject/26857654/?from=showing',
#  'https://movie.douban.com/subject/26871669/?from=showing',
#  'https://movie.douban.com/subject/27040737/?from=showing',
#  'https://movie.douban.com/subject/27042871/?from=showing',
#  'https://movie.douban.com/subject/27059060/?from=showing',
#  'https://movie.douban.com/subject/27060077/?from=showing',
#  'https://movie.douban.com/subject/27063305/?from=showing',
#  'https://movie.douban.com/subject/27150225/?from=showing',
#  'https://movie.douban.com/subject/27179414/?from=showing',
#  'https://movie.douban.com/subject/27185558/?from=showing',
#  'https://movie.douban.com/subject/27202819/?from=showing',
#  'https://movie.douban.com/subject/27624661/?from=showing',
#  'https://movie.douban.com/subject/27662707/?from=showing',
#  'https://movie.douban.com/subject/27663742/?from=showing',
#  'https://movie.douban.com/subject/27666591/?from=showing',
#  'https://movie.douban.com/subject/30164448/?from=showing',
#  'https://movie.douban.com/subject/30183667/?from=showing',
#  'https://movie.douban.com/subject/30334073/?from=showing',
#  'https://movie.douban.com/subject/30447810/?from=showing',
#  'https://movie.douban.com/subject/30464313/?from=showing',
#  'https://movie.douban.com/subject/30465860/?from=showing',
#  'https://movie.douban.com/subject/32513733/?from=showing',
#  'https://movie.douban.com/subject/4844731/?from=showing',
#  'https://movie.douban.com/subject/5300054/?from=showing'}

# %%
for line in html_content.split():
    match = image_pattern.findall(line)
    if match:
        print(match[0])
# Out:
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553279350.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551331455.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551353482.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551872873.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551249211.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2552080122.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549558913.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549234765.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2552522615.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2545472803.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549523952.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551172384.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549177902.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553090666.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2552542543.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2552608202.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2552463974.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2544987866.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2546335362.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2550873121.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549910141.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2550531644.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2548652745.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2549353234.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551444674.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2548549246.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2551693460.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2553811303.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2530572643.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2510130772.jpg
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2529571873.jpg

# %%
plt.figure(figsize = (20,8),dpi =100)

# %%
import re

# %%
def token(string):
    return ' '.join(re.findall('[\w|\d]+',string))

# %%
all_articles = [token(str(a)) for a in all_articles]

# %%
all_articles[:10]
# Out:
# ['此外 自本周 6月12日 起 除小米手机6等15款机型外 其余机型已暂停更新发布 含开发版 体验版内测 稳定版暂不受影响 以确保工程师可以集中全部精力进行系统优化工作 有人猜测这也是将精力主要用到MIUI 9的研发之中 MIUI 8去年5月发布 距今已有一年有余 也是时候更新换代了 当然 关于MIUI 9的确切信息 我们还是等待官方消息',
#  '骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器 高通强调 不会因为只考虑性能而去屏蔽掉小核心 相反 他们正联手微软 找到一种适合桌面平台的 兼顾性能和功耗的完美方案 报道称 微软已经拿到了一些新的源码 以便Windows 10更好地理解big little架构 资料显示 骁龙835作为一款集成了CPU GPU 基带 蓝牙 Wi Fi的SoC 比传统的Wintel方案可以节省至少30 的PCB空间 按计划 今年Q4 华硕 惠普 联想将首发骁龙835 Win10电脑 预计均是二合一形态的产品 当然 高通骁龙只是个开始 未来也许还能见到三星Exynos 联发科 华为麒麟 小米澎湃等进入Windows 10桌面平台',
投资者风格将更加稳健 更加偏好业绩稳定 流动性好 风险低的优质蓝筹股 银行股具估值优势 6月22日 A股金融股表现强势 板块涨幅达1 19 据平安证券统计 在222只纳入MSCI指数的A股股票中 金融板块市值占比达41 32 其中银行 证券和保险子板块的市值占比分别为27 30 7 75 和6 24 多家券商研究报告认为 银行等金融股受到纳入MSCI指数的提振 未来更多境外资金将进入金融股 华泰证券表示 在纳入MSCI指数之后 A股将迎来约850亿元人民币的增量资金 其中 考虑到222只股票中 金融股市值占比约42 并且金融股体量大 流动性强 估值低 符合境外资金偏好 有望迎来超过权重的资金比例 预计金融股有望吸引增量资金约350亿元人民币 新富资本证券投资中心研究总监廖云龙认为 银行股脱颖而出的主要原因是低估值 市场预期银行股基本面改善 同时市场整体风格偏保守 偏爱低估值 22日银行股的大涨是市场风格的延续 是投资者对龙头股和对低估值的防御性选择 东方财富choice统计的一季度末QFII重仓股数据显示 银行股是QFII关注的重点之一 在前五十大重仓股中 北京银行 南京银行 宁波银行 上海银行榜上有名']

# %%
text = ' '
for a in all_articles:
    text += a 
print('length of text:{}'.format(len(text)))
# Out:
# length of text:37412507

# %%
TEXT = text

# %%
from functools import reduce

# %%
text_from_reduce =  reduce(lambda a1,a2:a1 + a2,all_articles[:10])

# %%
print(text_from_reduce)
# Out:
# 此外 自本周 6月12日 起 除小米手机6等15款机型外 其余机型已暂停更新发布 含开发版 体验版内测 稳定版暂不受影响 以确保工程师可以集中全部精力进行系统优化工作 有人猜测这也是将精力主要用到MIUI 9的研发之中 MIUI 8去年5月发布 距今已有一年有余 也是时候更新换代了 当然 关于MIUI 9的确切信息 我们还是等待官方消息骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器 高通强调 不会因为只考虑性能而去屏蔽掉小核心 相反 他们正联手微软 找到一种适合桌面平台的 兼顾性能和功耗的完美方案 报道称 微软已经拿到了一些新的源码 以便Windows 10更好地理解big little架构 资料显示 骁龙835作为一款集成了CPU GPU 基带 蓝牙 Wi Fi的SoC 比传统的Wintel方案可以节省至少30 的PCB空间 按计划 今年Q4 华硕 惠普 联想将首发骁龙835 Win10电脑 预计均是二合一形态的产品 当然 高通骁龙只是个开始 未来也许还能见到三星Exynos 联发科 华为麒麟 小米澎湃等进入Windows 10桌面平台此前的一加3T搭载的是3400mAh电池 DashCharge快充规格为5V 4A 至于电池缩水 可能与刘作虎所说 一加手机5要做市面最轻薄大屏旗舰的设定有关 按照目前掌握的资料 一加手机5拥有5 5寸1080P三星AMOLED显示屏 6G 8GB RAM 64GB 128GB ROM 双1600万摄像头 备货量 惊喜 根据京东泄露的信息 一加5起售价是xx99元 应该是在2799 2899 2999中的某个这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车 新华社记者张立云摄原标题 44岁女子跑深圳约会网友被拒 暴雨中裸身奔走 深圳交警微博称 昨日清晨交警发现有一女子赤裸上身 行走在南坪快速上 期间还起了轻生年头 一辅警发现后赶紧为其披上黄衣 并一路劝说她 那么事发时 到底都发生了些什么呢 南都记者带您一起还
器 那就是已经上市销售的 OPPO R11 骁龙 660 尽管并非旗舰芯片 但在多核新能上比去年骁龙 820 强 单核改进也很明显 所以放在今年仍可以让很多手机变成高端机 不过 由于 OPPO 与高通签署了排他性协议 可以独占两三个月时间 考虑到夏普既然开始测试新机了 说明只要等独占时期一过 夏普就能发布骁龙 660 新品了 按照之前被曝光的渲染图了解 夏普的新机核心竞争优势还是全面屏 因为从 2013 年推出全球首款全面屏手机 EDGEST 302SH 至今 夏普手机推出了多达 28 款的全面屏手机 在 5 月份的媒体沟通会上 惠普罗忠生表示 我敢打赌 12 个月之后 在座的各位手机都会换掉 因为全面屏时代的到来 我们怀揣的手机都将成为传统手机沙漠雄鹰 震荡有利消化套牢筹 ...

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/wy/Desktop/python32期开班环境（必装）/3_种子软件（必装）/study/2019NLP',
#  '/Users/wy/anaconda3/lib/python37.zip',
#  '/Users/wy/anaconda3/lib/python3.7',
#  '/Users/wy/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/Users/wy/anaconda3/lib/python3.7/site-packages',
#  '/Users/wy/anaconda3/lib/python3.7/site-packages/aeosa',
#  '/Users/wy/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/wy/.ipython']

# %%
 import jieba

# %%
def cut(string): return list(jieba.cut(string))

# %%
cut('阿三，这是一个测试啊，呵呵！')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/g3/9mhby4g17h746xkcmmzl483w0000gn/T/jieba.cache
# Loading model cost 0.595 seconds.
# Prefix dict has been built succesfully.
# ['阿三', '，', '这是', '一个', '测试', '啊', '，', '呵呵', '！']

# %%
ALL_TOKENS = cut(TEXT)

# %%
ALL_TOKENS
# Out:
# [' ',
#  '此外',
#  ' ',
#  '自',
#  '本周',
#  ' ',
#  '6',
#  '月',
#  '12',
#  '日',
#  ' ',
#  '起',
#  ' ',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  ' ',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  ' ',
#  '含',
#  '开发',
#  '版',
#  ' ',
#  '体验版',
#  '内测',
#  ' ',
#  '稳定版',
#  '暂不受',
#  '影响',
#  ' ',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  ' ',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI',
#  ' ',
#  '9',
#  '的',
#  '研发',
#  '之中',
#  ' ',
#  'MIUI',
#  ' ',
#  '8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  ' ',
#  '距今已有',
#  '一年',
#  '有余',
#  ' ',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  ' ',
#  '当然',
#  ' ',
#  '关于',
#  'MIUI',
#  ' ',
#  '9',
#  '的',
#  '确切',
#  '信息',
#  ' ',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows',
#  ' ',
#  '10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
#  ' ',
#  '高通',
#  '强调',
#  ' ',
#  '不会',
#  '因为',
#  '只',
#  '考虑',
#  '性能',
#  '而',
#  '去',
#  '屏蔽掉',
#  '小',
#  '核心',
#  ' ',
#  '相反',
#  ' ',
#  '他们',
#  '正',
#  '联手',
#  '微软',
#  ' ',
#  '找到',
#  '一种',
#  '适合',
#  '桌面',
#  '平台',
#  '的',
#  ' ',
#  '兼顾',
#  '性能',
#  '和',
#  '功耗',
#  '的',
#  '完美',
#  '方案',
#  ' ',
#  '报道',
#  '称',
#  ' ',
#  '微软',
#  '已经',
#  '拿到',
#  '了',
#  '一些',
#  '新',
#  '的',
#  '源码',
#  ' ',
#  '以便',
#  'Windows',
#  ' ',
#  '10',
#  '更好',
#  '地',
#  '理解',
#  'big',
#  ' ',
#  'little',
#  '架构',
#  ' ',
#  '资料',
#  '显示',
#  ' ',
#  '骁龙',
#  '835',
#  '作为',
#  '一款',
#  '集成',
#  '了',
#  'CPU',
#  ' ',
#  'GPU',
#  ' ',
#  '基带',
#  ' ',
#  '蓝牙',
#  ' ',
#  'Wi',
#  ' ',
#  'Fi',
#  '的',
#  'SoC',
#  ' ',
#  '比',
#  '传统',
#  '的',
#  'Wintel',
#  '方案',
#  '可以',
#  '节省',
#  '至少',
#  '30',
#  ' ',
#  '的',
#  'PCB',
#  '空间',
#  ' ',
#  '按计划',
#  ' ',
#  '今年',
#  'Q4',
#  ' ',
#  '华硕',
#  ' ',
#  '惠普',
#  ' ',
#  '联想',
#  '将',
#  '首发',
#  '骁龙',
#  '835',
#  ' ',
#  'Win10',
#  '电脑',
#  ' ',
#  '预计',
#  '均',
#  '是',
#  '二合一',
#  '形态',
#  '的',
#  '产品',
#  ' ',
#  '当然',
#  ' ',
#  '高通',
#  '骁龙',
#  '只是',
#  '个',
#  '开始',
#  ' ',
#  '未来',
#  '也许',
#  '还',
#  '能',
#  '见到',
#  '三星',
#  'Exynos',
#  ' ',
#  '联发科',
#  ' ',
#  '华为',
#  '麒麟',
#  ' ',
#  '小米',
#  '澎湃',
#  '等',
#  '进入',
#  'Windows',
#  ' ',
#  '10',
#  '桌面',
#  '平台',
#  '此前',
#  '的',
#  '一加',
#  '3T',
#  '搭载',
#  '的',
#  '是',
#  '3400mAh',
#  '电池',
#  ' ',
#  'DashCharge',
#  '快充',
#  '规格',
#  '为',
#  '5V',
#  ' ',
#  '4A',
#  ' ',
#  '至于',
#  '电池',
#  '缩水',
#  ' ',
#  '可能',
#  '与',
#  '刘作',
#  '虎',
#  '所说',
#  ' ',
#  '一加',
#  '手机',
#  '5',
#  '要',
#  '做',
#  '市面',
#  '最',
#  '轻薄',
#  '大屏',
#  '旗舰',
#  '的',
#  '设定',
#  '有关',
#  ' ',
#  '按照',
#  '目前',
#  '掌握',
#  '的',
#  '资料',
#  ' ',
#  '一加',
#  '手机',
#  '5',
#  '拥有',
#  '5',
#  ' ',
#  '5',
#  '寸',
#  '1080P',
#  '三星',
#  'AMOLED',
#  '显示屏',
#  ' ',
#  '6G',
#  ' ',
#  '8GB',
#  ' ',
#  'RAM',
#  ' ',
#  '64GB',
#  ' ',
#  '128GB',
#  ' ',
#  'ROM',
#  ' ',
#  '双',
#  '1600',
#  '万',
#  '摄像头',
#  ' ',
#  '备货',
#  '量',
#  ' ',
#  '惊喜',
#  ' ',
#  '根据',
#  '京东',
#  '泄露',
#  '的',
#  '信息',
#  ' ',
#  '一加',
#  '5',
#  '起',
#  '售价',
#  '是',
#  'xx99',
#  '元',
#  ' ',
#  '应该',
#  '是',
#  '在',
#  '2799',
#  ' ',
#  '2899',
#  ' ',
#  '2999',
#  '中',
#  '的',
#  '某个',
#  '这是',
#  '6',
#  '月',
#  '18',
#  '日',
#  '在',
#  '葡萄牙',
#  '中部',
#  '大',
#  '佩德罗',
#  '冈',
#  '地区',
#  '拍摄',
#  '的',
#  '被',
#  '森林',
#  '大火',
#  '烧毁',
#  '的',
#  '汽车',
#  ' ',
#  '新华社',
#  '记者',
#  '张立云',
#  '摄原',
#  '标题',
#  ' ',
#  '44',
#  '岁',
#  '女子',
#  '跑',
#  '深圳',
#  '约会',
#  '网友',
#  '被',
#  '拒',
#  ' ',
#  '暴雨',
#  '中',
#  '裸身',
#  '奔走',
#  ' ',
#  '深圳',
#  '交警',
#  '微博称',
#  ' ',
#  '昨日',
#  '清晨',
#  '交警',
#  '发现',
#  '有',
#  '一',
#  '女子',
#  '赤裸',
#  '上身',
#  ' ',
#  '行走',
#  '在',
#  '南坪',
#  '快速',
#  '上',
#  ' ',
#  '期间',
#  '还',
#  '起',
#  '了',
#  '轻生',
#  '年头',
#  ' ',
#  '一辅警',
#  '发现',
#  '后',
#  '赶紧',
#  '为',
#  '其',
#  '披上',
#  '黄衣',
#  ' ',
#  '并',
#  '一路',
#  '劝说',
#  '她',
#  ' ',
#  '那么',
#  '事发',
#  '时',
#  ' ',
#  '到底',
#  '都',
#  '发生',
#  '了',
#  '些',
#  '什么',
#  '呢',
#  ' ',
#  '南',
#  '都',
#  '记者',
#  '带',
#  '您',
#  '一起',
#  '还原',
#  '现场',
#  ' ',
#  '南',
#  '都',
#  '记者',
#  '在',
#  '龙岗',
#  '大队',
#  '坂田',
#  '中队',
#  '见到',
#  '了',
#  '辅警',
#  '刘青',
#  ' ',
#  '发现',
#  '女生',
#  '的',
#  '辅警',
#  ' ',
#  '一位',
#  '外表',
#  '高大',
#  '帅气',
#  ' ',
#  '说话',
#  '略带',
#  '些',
#  '腼腆',
#  '的',
#  '90',
#  '后',
#  '青年',
#  ' ',
#  '刘青',
#  '介绍',
#  ' ',
#  '6',
#  '月',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '36',
#  '分',
#  ' ',
#  '他',
#  '正在',
#  '环城',
#  '南路',
#  '附近',
#  '值勤',
#  ' ',
#  '接到',
#  '中队',
#  '关于',
#  '一位',
#  '女子',
#  '裸身',
#  '进入',
#  '机动车',
#  '可能',
#  '有',
#  '危险',
#  '的',
#  '警情',
#  ' ',
#  '随后',
#  '骑着',
#  '小',
#  '铁骑',
#  '开始',
#  '沿路',
#  '寻找',
#  ' ',
#  '大概',
#  '花',
#  '了',
#  '十多分钟',
#  '在',
#  '南坪',
#  '大道',
#  '坂田',
#  '出口',
#  '往',
#  '龙岗',
#  '方向',
#  '的',
#  '逆行',
#  '辅道',
#  '上',
#  '发现',
#  '该',
#  '女子',
#  ' ',
#  '女子',
#  '身上',
#  '一丝不挂',
#  '地逆',
#  '车流',
#  '而行',
#  ' ',
#  '时',
#  '走时',
#  '停',
#  ' ',
#  '时',
#  '坐',
#  '时',
#  '躺',
#  ' ',
#  '险象环生',
#  ' ',
#  '刘青停',
#  '好',
#  '小',
#  '铁骑',
#  ' ',
#  '和',
#  '另外',
#  '一名',
#  '巡防',
#  '员',
#  '追',
#  '了',
#  '上去',
#  ' ',
#  '发现',
#  '女子',
#  '的',
#  '情绪',
#  '很',
#  '低落',
#  ' ',
#  '话',
#  '不',
#  '多',
#  ' ',
#  '刘青',
#  '尝试',
#  '和',
#  '女子',
#  '交流',
#  ' ',
#  '劝说',
#  '女子',
#  '离开',
#  ' ',
#  '可',
#  '女子',
#  '并',
#  '不',
#  '愿意',
#  '接受',
#  ' ',
#  '继续',
#  '缓慢',
#  '地往',
#  '南坪',
#  '快速路',
#  '的',
#  '主干道',
#  '上',
#  '走',
#  '去',
#  ' ',
#  '此时',
#  '路边',
#  '上',
#  '已经',
#  '聚集',
#  '了',
#  '很',
#  '市民',
#  '围观',
#  ' ',
#  '为了',
#  '不',
#  '刺激',
#  '女子',
#  '的',
#  '情绪',
#  ' ',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '一边',
#  '盯',
#  '着',
#  '女子',
#  '一边',
#  '驱赶',
#  '着',
#  '围观',
#  '的',
#  '群众',
#  ' ',
#  '现场',
#  '还原',
#  ' ',
#  '从',
#  '警方',
#  '提供',
#  '的',
#  '一份',
#  '视频',
#  '了解',
#  '到',
#  ' ',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '25',
#  '分',
#  ' ',
#  '女子',
#  '出现',
#  '在',
#  '坂雪岗',
#  '大道',
#  '与',
#  '环城',
#  '南路',
#  '的',
#  '监控',
#  '视频',
#  '中',
#  ' ',
#  '此时',
#  '女子',
#  '还',
#  '穿着',
#  '白色',
#  '的',
#  '内裤',
#  ' ',
#  '正',
#  '沿着',
#  '坂雪岗',
#  '大道',
#  '往',
#  '南坪',
#  '快速',
#  '的',
#  '方向',
#  '缓慢',
#  '地',
#  '走',
#  '着',
#  ' ',
#  '当时',
#  '正值',
#  '上班',
#  '高峰期',
#  ' ',
#  '十字路口',
#  '的',
#  '车流',
#  '已经',
#  '排起',
#  '了',
#  '长队',
#  ' ',
#  '当',
#  '女子',
#  '出现',
#  '时',
#  ' ',
#  '路上',
#  '的',
#  '市民',
#  '纷纷',
#  '驻足',
#  '观望',
#  ' ',
#  '不少',
#  '车辆',
#  '也',
#  '放慢',
#  '了',
#  '速度',
#  ' ',
#  '但',
#  '女子',
#  '并',
#  '不',
#  '为',
#  '市民',
#  '观望',
#  '停下',
#  '脚步',
#  ' ',
#  '依然',
#  '缓慢',
#  '走',
#  '着',
#  ' ',
#  '当',
#  '女子',
#  '行进',
#  '到',
#  '十字路口',
#  '中间',
#  '时',
#  ' ',
#  '一辆',
#  '大',
#  '货车',
#  '挡住',
#  '了',
#  '镜头',
#  ' ',
#  '但是',
#  '当',
#  '女子',
#  '再次出现',
#  '镜头',
#  '时',
#  ' ',
#  '可以',
#  '发现',
#  '女子',
#  '已经',
#  '没',
#  '穿',
#  '内裤',
#  '了',
#  ' ',
#  '全身',
#  '裸露',
#  '继续',
#  '朝着',
#  '南坪',
#  '快速',
#  '方向',
#  '走',
#  '去',
#  ' ',
#  '记者',
#  '发现',
#  ' ',
#  '视频',
#  '中',
#  '女子',
#  '周围',
#  '并',
#  '没有',
#  '人',
#  '尾随',
#  '或者',
#  '上前',
#  '劝止',
#  '的',
#  '市民',
#  ' ',
#  '一',
#  '大清早',
#  '路上',
#  '看到',
#  '这样',
#  '的',
#  '情况',
#  ' ',
#  '恐怕',
#  '大家',
#  '都',
#  '没',
#  '办法',
#  '淡定',
#  ' ',
#  '面对',
#  '这一',
#  '情况',
#  ' ',
#  '刘青',
#  '表示',
#  ' ',
#  '一',
#  '开始',
#  '根本',
#  '不敢',
#  '看',
#  '她',
#  ' ',
#  '心里',
#  '挺',
#  '别扭',
#  ' ',
#  '感觉',
#  '很',
#  '尴尬',
#  ' ',
#  '但',
#  '当',
#  '刘青',
#  '跟随',
#  '女子',
#  '上',
#  '了',
#  '南坪',
#  '快速路',
#  '主干道',
#  '时',
#  ' ',
#  '女子',
#  '作出',
#  '了',
#  '让',
#  '人',
#  '意想不到',
#  '的',
#  '举动',
#  ' ',
#  '她',
#  '突然',
#  '靠近',
#  '护栏',
#  '要',
#  '从',
#  '上面',
#  '跳下去',
#  ' ',
#  '刘青',
#  '赶忙',
#  '冲上去',
#  '拉住',
#  '了',
#  '女子',
#  '的',
#  '手',
#  ' ',
#  '将',
#  '其',
#  '控制',
#  '住',
#  '并',
#  '远离',
#  '护栏',
#  ' ',
#  '碍于',
#  '女子',
#  '没有',
#  '穿衣服',
#  ' ',
#  '刘青递',
#  '上',
#  '衣服',
#  ' ',
#  '女子',
#  '没',
#  '接受',
#  '还',
#  '把',
#  '衣服',
#  '扔',
#  '到',
#  '排水沟',
#  '里',
#  ' ',
#  '继续',
#  '往前走',
#  ' ',
#  '没',
#  '办法',
#  '刘青',
#  '只能',
#  '紧紧',
#  '拉',
#  '着',
#  '她',
#  '的',
#  '一只',
#  '手',
#  '跟',
#  '在',
#  '后面',
#  ' ',
#  '刘青',
#  '一路上',
#  '耐心',
#  '地',
#  '开导',
#  '安慰',
#  '她',
#  ' ',
#  '但',
#  '只',
#  '听到',
#  '她',
#  '不断',
#  '地',
#  '重复',
#  '着',
#  '一句',
#  '话',
#  ' ',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  ' ',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '的',
#  ' ',
#  '期间',
#  '她',
#  '还',
#  '不时',
#  '试图',
#  '挣脱',
#  '刘青',
#  '的',
#  ...]

# %%
valida_tokens = [t for t in ALL_TOKENS if t.strip() and t !='n']

# %%
len(ALL_TOKENS)
# Out:
# 21906853

# %%
len(valida_tokens)
# Out:
# 17221785

# %%
valida_tokens[:20]
# Out:
# ['此外',
#  '自',
#  '本周',
#  '6',
#  '月',
#  '12',
#  '日',
#  '起',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  '其余',
#  '机型',
#  '已']

# %%
from collections import Counter

# %%
Counter({1,1,2,2,2,3,1,0})
# Out:
# Counter({0: 1, 1: 1, 2: 1, 3: 1})

# %%
words_count = Counter(valida_tokens)

# %%
words_count
# Out:
# Counter({'此外': 4239,
#          '自': 4826,
#          '本周': 486,
#          '6': 36059,
#          '月': 189525,
#          '12': 11071,
#          '日': 169920,
#          '起': 5263,
#          '除': 1362,
#          '小米': 287,
#          '手机': 2997,
#          '等': 58383,
#          '15': 9263,
#          '款': 701,
#          '机型': 139,
#          '外': 3291,
#          '其余': 482,
#          '已': 21046,
#          '暂停': 834,
#          '更新': 623,
#          '发布': 7840,
#          '含': 710,
#          '开发': 3911,
#          '版': 913,
#          '体验版': 1,
#          '内测': 6,
#          '稳定版': 1,
#          '暂不受': 1,
#          '影响': 8135,
#          '以': 38168,
#          '确保': 2854,
#          '工程师': 523,
#          '可以': 13287,
#          '集中': 2910,
#          '全部': 3790,
#          '精力': 261,
#          '进行': 25986,
#          '系统优化': 1,
#          '工作': 20722,
#          '有人': 1847,
#          '猜测': 209,
#          '这': 22761,
#          '也': 47399,
#          '是': 100288,
#          '将': 61657,
#          '主要': 9804,
#          '用到': 41,
#          'MIUI': 5,
#          '9': 13419,
#          '的': 703820,
#          '研发': 3216,
#          '之中': 652,
#          '8': 14692,
#          '去年': 6330,
#          '5': 64720,
#          '距今已有': 22,
#          '一年': 3203,
#          '有余': 30,
#          '时候': 3067,
#          '更新换代': 34,
#          '了': 121904,
#          '当然': 880,
#          '关于': 4597,
#          '确切': 68,
#          '信息': 7725,
#          '我们': 19982,
#          '还是': 5133,
#          '等待': 882,
#          '官方消息': 10,
#          '骁龙': 55,
#          '835': 24,
#          '作为': 10385,
#          '唯一': 1367,
#          '通过': 18167,
#          'Windows': 49,
#          '10': 15489,
#          '桌面': 109,
#          '平台': 8298,
#          '认证': 664,
#          'ARM': 4,
#          '处理器': 105,
#          '高通': 73,
#          '强调': 3181,
#          '不会': 3786,
#          '因为': 5593,
#          '只': 4572,
#          '考虑': 2345,
#          '性能': 437,
#          '而': 17404,
#          '去': 7291,
#          '屏蔽掉': 2,
#          '小': 6574,
#          '核心': 3311,
#          '相反': 230,
#          '他们': 13878,
#          '正': 4777,
#          '联手': 413,
#          '微软': 340,
#          '找到': 1826,
#          '一种': 4035,
#          '适合': 812,
#          '兼顾': 203,
#          '和': 134220,
#          '功耗': 22,
#          '完美': 465,
#          '方案': 2844,
#          '报道': 9687,
#          '称': 7460,
#          '已经': 12235,
#          '拿到': 1059,
#          '一些': 9377,
#          '新': 23925,
#          '源码': 2,
#          '以便': 402,
#          '更好': 2858,
#          '地': 12764,
#          '理解': 1283,
#          'big': 2,
#          'little': 1,
#          '架构': 217,
#          '资料': 1904,
#          '显示': 8471,
#          '一款': 598,
#          '集成': 198,
#          'CPU': 57,
#          'GPU': 14,
#          '基带': 3,
#          '蓝牙': 28,
#          'Wi': 12,
#          'Fi': 12,
#          'SoC': 2,
#          '比': 23334,
#          '传统': 7068,
#          'Wintel': 3,
#          '节省': 273,
#          '至少': 2482,
#          '30': 8923,
#          'PCB': 14,
#          '空间': 3598,
#          '按计划': 193,
#          '今年': 13936,
#          'Q4': 8,
#          '华硕': 11,
#          '惠普': 20,
#          '联想': 222,
#          '首发': 489,
#          'Win10': 9,
#          '电脑': 854,
#          '预计': 4389,
#          '均': 4423,
#          '二合一': 1,
#          '形态': 363,
#          '产品': 8906,
#          '只是': 2397,
#          '个': 23044,
#          '开始': 11177,
#          '未来': 8199,
#          '也许': 532,
#          '还': 21786,
#          '能': 12159,
#          '见到': 507,
#          '三星': 340,
#          'Exynos': 4,
#          '联发科': 17,
#          '华为': 319,
#          '麒麟': 84,
#          '澎湃': 254,
#          '进入': 9193,
#          '此前': 3154,
#          '一加': 51,
#          '3T': 1,
#          '搭载': 504,
#          '3400mAh': 1,
#          '电池': 444,
#          'DashCharge': 1,
#          '快充': 7,
#          '规格': 256,
#          '为': 58103,
#          '5V': 3,
#          '4A': 47,
#          '至于': 403,
#          '缩水': 91,
#          '可能': 9902,
#          '与': 58317,
#          '刘作': 3,
#          '虎': 236,
#          '所说': 293,
#          '要': 21406,
#          '做': 8634,
#          '市面': 6,
#          '最': 8965,
#          '轻薄': 18,
#          '大屏': 35,
#          '旗舰': 90,
#          '设定': 380,
#          '有关': 6292,
#          '按照': 4632,
#          '目前': 16852,
#          '掌握': 1293,
#          '拥有': 3178,
#          '寸': 23,
#          '1080P': 2,
#          'AMOLED': 41,
#          '显示屏': 110,
#          '6G': 1,
#          '8GB': 9,
#          'RAM': 15,
#          '64GB': 10,
#          '128GB': 9,
#          'ROM': 14,
#          '双': 904,
#          '1600': 130,
#          '万': 3389,
#          '摄像头': 393,
#          '备货': 15,
#          '量': 1298,
#          '惊喜': 278,
#          '根据': 6920,
#          '京东': 683,
#          '泄露': 390,
#          '售价': 288,
#          'xx99': 1,
#          '元': 6833,
#          '应该': 2792,
#          '在': 264633,
#          '2799': 1,
#          '2899': 3,
#          '2999': 3,
#          '中': 77935,
#          '某个': 188,
#          '这是': 11351,
#          '18': 8429,
#          '葡萄牙': 1224,
#          '中部': 1063,
#          '大': 17644,
#          '佩德罗': 87,
#          '冈': 6,
#          '地区': 10979,
#          '拍摄': 5481,
#          '被': 25288,
#          '森林': 1288,
#          '大火': 147,
#          '烧毁': 39,
#          '汽车': 5223,
#          '新华社': 142462,
#          '记者': 62276,
#          '张立云': 2,
#          '摄原': 12,
#          '标题': 1408,
#          '44': 648,
#          '岁': 8731,
#          '女子': 3715,
#          '跑': 2774,
#          '深圳': 2741,
#          '约会': 99,
#          '网友': 1821,
#          '拒': 124,
#          '暴雨': 687,
#          '裸身': 3,
#          '奔走': 66,
#          '交警': 347,
#          '微博称': 12,
#          '昨日': 796,
#          '清晨': 590,
#          '发现': 8559,
#          '有': 46556,
#          '一': 11369,
#          '赤裸': 15,
#          '上身': 53,
#          '行走': 549,
#          '南坪': 30,
#          '快速': 2526,
#          '上': 48836,
#          '期间': 5085,
#          '轻生': 59,
#          '年头': 136,
#          '一辅警': 2,
#          '后': 28679,
#          '赶紧': 198,
#          '其': 11646,
#          '披上': 64,
#          '黄衣': 7,
#          '并': 26575,
#          '一路': 19209,
#          '劝说': 105,
#          '她': 12951,
#          '那么': 2006,
#          '事发': 635,
#          '时': 18995,
#          '到底': 642,
#          '都': 28042,
#          '发生': 8363,
#          '些': 177,
#          '什么': 3491,
#          '呢': 1402,
#          '南': 1079,
#          '带': 3057,
#          '您': 694,
#          '一起': 4931,
#          '还原': 178,
#          '现场': 5881,
#          '龙岗': 29,
#          '大队': 906,
#          '坂田': 6,
#          '中队': 210,
#          '辅警': 55,
#          '刘青': 31,
#          '女生': 286,
#          '一位': 3058,
#          '外表': 91,
#          '高大': 178,
#          '帅气': 39,
#          '说话': 342,
#          '略带': 25,
#          '腼腆': 55,
#          '90': 1465,
#          '青年': 3857,
#          '介绍': 7292,
#          '16': 8181,
#          '早上': 457,
#          '7': 16513,
#          '36': 1257,
#          '分': 7688,
#          '他': 37118,
#          '正在': 7686,
#          '环城': 42,
#          '南路': 90,
#          '附近': 3620,
#          '值勤': 15,
#          '接到': 923,
#          '机动车': 427,
#          '危险': 947,
#          '警情': 34,
#          '随后': 2399,
#          '骑着': 105,
#          '铁骑': 40,
#          '沿路': 20,
#          '寻找': 1402,
#          '大概': 342,
#          '花': 1232,
#          '十多分钟': 14,
#          '大道': 729,
#          '出口': 2200,
#          '往': 508,
#          '方向': 2429,
#          '逆行': 23,
#          '辅道': 5,
#          '该': 9780,
#          '身上': 963,
#          '一丝不挂': 4,
#          '地逆': 2,
#          '车流': 64,
#          '而行': 125,
#          '走时': 10,
#          '停': 457,
#          '坐': 533,
#          '躺': 292,
#          '险象环生': 8,
#          '刘青停': 2,
#          '好': 11871,
#          '另外': 2021,
#          '一名': 8107,
#          '巡防': 21,
#          '员': 899,
#          '追': 229,
#          '上去': 131,
#          '情绪': 913,
#          '很': 9207,
#          '低落': 24,
#          '话': 791,
#          '不': 28420,
#          '多': 18152,
#          '尝试': 988,
#          '交流': 5354,
#          '离开': 1486,
#          '可': 11077,
#          '愿意': 1350,
#          '接受': 5826,
#          '继续': 6952,
#          '缓慢': 315,
#          '地往': 8,
#          '快速路': 60,
#          '主干道': 56,
#          '走': 4719,
#          '此时': 448,
#          '路边': 252,
#          '聚集': 726,
#          '市民': 3429,
#          '围观': 132,
#          '为了': 4643,
#          '刺激': 524,
#          '一边': 976,
#          '盯': 131,
#          '着': 13980,
#          '驱赶': 42,
#          '群众': 5297,
#          '从': 29693,
#          '警方': 4265,
#          '提供': 12182,
#          '一份': 1888,
#          '视频': 2929,
#          '了解': 7623,
#          '到': 30451,
#          '25': 7435,
#          '出现': 7608,
#          '坂雪岗': 4,
#          '监控': 945,
#          '穿着': 330,
#          '白色': 474,
#          '内裤': 24,
#          '沿着': 382,
#          '当时': 3175,
#          '正值': 417,
#          '上班': 367,
#          '高峰期': 174,
#          '十字路口': 80,
#          '排起': 33,
#          '长队': 74,
#          '当': 3397,
#          '路上': 902,
#          '纷纷': 1366,
#          '驻足': 146,
#          '观望': 271,
#          '不少': 4548,
#          '车辆': 2199,
#          '放慢': 41,
#          '速度': 1784,
#          '但': 23362,
#          '停下': 76,
#          '脚步': 325,
#          '依然': 2130,
#          '行进': 261,
#          '中间': 441,
#          '一辆': 1276,
#          '货车': 522,
#          '挡住': 72,
#          '镜头': 367,
#          '但是': 3871,
#          '再次出现': 54,
#          '没': 2591,
#          '穿': 742,
#          '全身': 134,
#          '裸露': 113,
#          '朝着': 233,
#          '周围': 641,
#          '没有': 13997,
#          '人': 30575,
#          '尾随': 34,
#          '或者': 3079,
#          '上前': 134,
#          '劝止': 2,
#          '大清早': 8,
#          '看到': 4399,
#          '这样': 5822,
#          '情况': 9444,
#          '恐怕': 270,
#          '大家': 3297,
#          '办法': 1838,
#          '淡定': 55,
#          '面对': 2432,
#          '这一': 5345,
#          '表示': 22175,
#          '根本': 977,
#          '不敢': 478,
#          '看': 5722,
#          '心里': 643,
#          '挺': 445,
#          '别扭': 16,
#          '感觉': 1558,
#          '尴尬': 286,
#          '跟随': 440,
#          '作出': 2602,
#          '让': 18757,
#          '意想不到': 53,
#          '举动': 265,
#          '突然': 1034,
#          '靠近': 342,
#          '护栏': 80,
#          '上面': 362,
#          '跳下去': 10,
#          '赶忙': 19,
#          '冲上去': 21,
#          '拉住': 4,
#          '手': 920,
#          '控制': 2707,
#          '住': 1617,
#          '远离': 309,
#          '碍于': 21,
#          '穿衣服': 18,
#          '刘青递': 2,
#          '衣服': 397,
#          '把': 11853,
#          '扔': 189,
#          '排水沟': 22,
#          '里': 10077,
#          '往前走': 41,
#          '只能': 1621,
#          '紧紧': 183,
#          '拉': 1601,
#          '一只': 1350,
#          '跟': 2058,
#          '后面': 329,
#          '一路上': 96,
#          '耐心': 404,
#          '开导': 21,
#          '安慰': 129,
#          '听到': 603,
#          '不断': 6213,
#          '重复': 372,
#          '一句': 558,
#          '要是': 179,
#          '你': 6959,
#          '遭遇': 1703,
#          '我': 21713,
#          '事': 2098,
#          '会': 17309,
#          '不时': 309,
#          '试图': 824,
#          '挣脱': 25,
#          '手要': 8,
#          '冲向': 99,
#          '往下跳': 4,
#          '就': 26691,
#          '牵': 74,
#          '天': 3328,
#          '下起': 4,
#          '大暴雨': 172,
#          '雨大': 2,
#          '连': 1380,
#          '眼睛': 460,
#          '睁不开': 5,
#          '说': 40081,
#          '瞬间': 568,
#          '雨': 364,
#          '透': 58,
#          '帮助': 5162,
#          '冒': 175,
#          '大雨': 255,
#          '四十分钟': 4,
#          '吧': 1250,
#          '来说': 2870,
#          '想': 3716,
#          '回家': 768,
#          '然后': 1218,
#          '递过来': 11,
#          '微博上': 106,
#          '照片': 52271,
#          '披着': 2,
#          '小心翼翼': 87,
#          '旁边': 305,
#          '场景': 754,
#          '南平': 67,
#          '下来': 843,
#          '带到': 258,
#          '派出所': 670,
#          '那': 2590,
#          '姑娘': 462,
#          '什么样': 410,
#          '事情': 1461,
#          '才': 3917,
#          '据': 10722,
#          '透露': 1575,
#          '姓': 65,
#          '陈': 1073,
#          '系': 660,
#          '湖北': 2478,
#          '家属': 735,
#          '反映': 1547,
#          '其有': 10,
#          '精神病': 53,
#          '史': 436,
#          '三天': 431,
#          '前': 13660,
#          '陈某': 291,
#          '老家': 228,
#          '来': 10977,
#          '受挫': 60,
#          '导致': 3834,
#          '异常': 422,
#          '遂': 155,
#          '产生': 3063,
#          '念头': 97,
#          '送往': 416,
#          '某': 1584,
#          '医院': 4146,
#          '治疗': 2117,
#          '大大': 395,
#          '君': 159,
#          '希望': 7863,
#          '早点': 41,
#          '康复': 586,
#          '其实': 1756,
#          '真爱': 14,
#          '到来': 1088,
#          '存在': 5138,
#          '年龄': 910,
#          '限制': 1628,
#          '你们': 733,
#          '因': 4901,
#          '善良': 84,
#          '原因': 3562,
#          '一众': 39,
#          '暖': 226,
#          '男点': 2,
#          'ZAN': 2,
#          '弓常': 2,
#          'yan': 3,
#          '桦': 7,
#          '问': 1095,
#          '这个': 8688,
#          '哥哥': 300,
#          '女票': 2,
#          '吗': 1784,
#          '原谅': 24,
#          '一辈子': 241,
#          '浪荡': 2,
#          '不羁': 16,
#          '爱': 1501,
#          '萨摩耶': 2,
#          '过不去': 16,
#          '嘛': 94,
#          '想想': 81,
#          '自己': 14006,
#          '家人': 1291,
#          '同时': 10798,
#          '感谢': 671,
#          '蜀黍': 12,
#          '火心': 2,
#          '聆听': 198,
#          '心灵': 226,
#          '点赞': 353,
#          '中華云盾': 2,
#          '警察': 1769,
#          '就是': 8003,
#          '需时': 3,
#          '申出': 2,
#          '援手': 49,
#          'Tomchlee': 2,
#          '帅': 27,
#          'SJ': 2,
#          '李赫海': 2,
#          'i': 48,
#          '木有': 4,
#          '男子': 3965,
#          '迷奸': 1,
#          '拍': 742,
#          '418': 16,
#          '女方': 36,
#          '20': 11881,
#          '50': 3279,
#          '号': 6632,
#          '上午': 2172,
#          '淮安市': 71,
#          '涟水县': 2,
#          '公安局': 835,
#          '刑警大队': 17,
#          '一个': 21937,
#          '奇怪': 106,
#          '报警': 489,
#          '电话': 1365,
#          '言语': 85,
#          '不清': 61,
#          '声称': 322,
#          '遭到': 832,
#          '侵害': 323,
#          '几个': 1330,
#          '关键词': 1433,
#          '令': 1318,
#          '民警': 1427,
#          '紧张': 1123,
#          '起来': 2656,
#          '受到': 3667,
#          'A股': 1973,
#          '纳入': 2269,
#          'MSCI': 1292,
#          '指数': 3957,
#          '利好': 460,
#          '消息': 3605,
#          '市场': 19029,
#          '周三': 197,
#          '再度': 749,
#          '上演': 1330,
#          '龙马': 23,
#          '行情': 906,
#          '周四': 145,
#          '金融股': 141,
#          '白马股': 104,
#          '表现': 2997,
#          '喜人': 50,
#          '尾盘': 240,
#          '跳水': 638,
#          '之后': 4770,
#          '仅': 3079,
#          '金融': 5616,
#          '板块': 1378,
#          '仍': 5630,
#          '维系': 46,
#          '红盘': 23,
#          '状态': 1956,
#          '分析': 3961,
#          '人士': 3337,
#          '认为': 11639,
#          '受益': 746,
#          '于': 17298,
#          '低': 2236,
#          '估值': 529,
#          '重获': 92,
#          '资金': 6566,
#          '青睐': 428,
#          '存量': 366,
#          '博弈': 248,
#          '格局': 1170,
#          '下': 18128,
#          '风格': 817,
#          '交替': 116,
#          '震荡': 698,
#          '料': 122,
#          '延续': 1212,
#          '流动性': 989,
#          '改善': 2716,
#          '经济': 22208,
#          '悲观': 86,
#          '预期': 2482,
#          '修正': 134,
#          '有助于': 1113,
#          '支撑': 1950,
#          '继而': 89,
#          '大盘': 374,
#          '逐步': 1834,
#          '向': 15203,
#          '九': 240,
#          '再现': 372,
#          '未能': 1010,
#          '上行': 417,
#          '态势': 1185,
#          '两市': 518,
#          '成交': 1469,
#          '小幅': 488,
#          '放量': 143,
#          '29': 5193,
#          '中信': 140,
#          '一级': 557,
#          '行业': 6515,
#          '收盘': 661,
#          '银行': 5991,
#          '非银行': 46,
#          '两个': 4158,
#          '收红': 39,
#          '分别': 5488,
#          '上涨': 3992,
#          '1': 35082,
#          '80': 1786,
#          '0': 11826,
#          '二级': 432,
#          '来看': 2608,
#          '股份制': 119,
#          '城商行': 53,
#          '涨幅': 2242,
#          '最高': 3452,
#          '达到': 5390,
#          '2': 33954,
#          '22': 7277,
#          '国有银行': 37,
#          '82': 311,
#          '信托': 384,
#          '及其': 1807,
#          '64': 350,
#          '保险': 1528,
#          '34': 1186,
#          '证券': 1486,
#          '06': 712,
#          '成分股': 180,
#          '共有': 2059,
#          '21': 7837,
#          '其中': 10635,
#          '招商银行': 94,
#          '最大': 6078,
#          '66': 370,
#          '贵阳': 861,
#          '3': 33893,
#          '65': 611,
#          '上海银行': 29,
#          '华夏银行': 46,
#          '浦发银行': 41,
#          '兴业银行': 67,
#          '超过': 7201,
#          '共': 4581,
#          '17': 7868,
#          '个股': 827,
#          '安信': 49,
#          '中国': 71180,
#          '太保': 30,
#          '居前': 316,
#          '两名': 1573,
#          '4': 60640,
#          '57': 498,
#          '04': 1032,
#          '西水股份': 4,
#          '华安': 41,
#          '人寿': 118,
#          '新华': 6665,
#          '相对而言': 54,
#          '券商': 587,
#          '股多': 1,
#          '下跌': 2849,
#          '近期': 2594,
#          '对': 50582,
#          '消息面': 47,
#          '宣布': 5117,
#          '2018': 1641,
#          '年': 123531,
#          '新兴': 1203,
#          '占': 4953,
#          '群体': 1186,
#          '国金': 24,
#          '李立峰': 7,
#          '团队': 4258,
#          '指出': 5061,
#          '最新': 2318,
#          '包含': 577,
#          '222': 124,
#          '剔除': 105,
#          '中等': 130,
#          '市值': 498,
#          '非': 2843,
#          '互联互通': 1137,
#          '交易': 3728,
#          '股票': 1227,
#          '以及': 10208,
#          '停牌': 262,
#          '标的': 430,
#          '由于': 5419,
#          '很多': 5800,
#          'A': 1025,
#          'H股': 52,
#          'EM': 6,
#          '权重': 223,
#          '由': 13075,
#          '上升': 2114,
#          '73': 342,
#          '40': 2590,
#          '11': 11012,
#          '泛': 82,
#          '消费': 3114,
#          '次之': 17,
#          '24': 6585,
#          '26': 6202,
#          '涵盖': 698,
#          '大部分': 1275,
#          '权重股': 80,
#          '动态': 901,
#          '加入': 2037,
#          '指': 1521,
#          '比高': 52,
#          '金融公司': 45,
#          '增加': 5500,
#          '近一半': 77,
#          '其他': 6419,
#          '稀释': 38,
#          '尽管': 2086,
#          '事件': 5186,
#          '短期': 1066,
#          '有所': 1601,
#          '提振': 342,
#          '中长期': 347,
#          '海外': 2835,
#          '增量': 349,
#          '升温': 324,
#          '短期内': 264,
#          '尚': 546,
#          '不能': 4328,
#          '有效': 4002,
#          '放大': 213,
#          '独': 64,
#          '乐乐': 15,
#          '情景': 211,
#          '难以': 1256,
#          '持续': 6932,
#          '难': 1358,
#          '改变': 2763,
#          '光大': 51,
#          '并未': 1157,
#          '引起': 1395,
#          '太大': 90,
#          '热情': 877,
#          '成交量': 528,
#          '较为': 979,
#          '平淡': 71,
#          '较大': 1592,
#          '变化': 2960,
#          '成长': 1718,
#          '股': 1010,
#          '题材股': 50,
#          '全天': 301,
#          '低迷': 397,
#          '表明': 1385,
#          '很少': 493,
#          '不同': 5431,
#          '之间': 3805,
#          '腾挪': 23,
#          '跷跷板': 19,
#          '使得': 1099,
#          '难有': 51,
#          '突破': 3090,
#          '中期': 399,
#          '依旧': 629,
#          '偏空': 12,
#          '维持': 1185,
#          '虽然': 4223,
#          '至今': 1600,
#          '夏普': 133,
#          '智能手机': 296,
#          '无法': 2745,
#          '排得': 2,
#          '完全': 2446,
#          '没落': 8,
#          '2013': 1558,
#          '退出': 1574,
#          '月份': 3190,
#          '官方': 1207,
#          '回归': 952,
#          '预示': 133,
#          '很快': 969,
#          '新机': 27,
#          '登场': 236,
#          '第一款': 48,
#          '登陆': 389,
#          '又': 8702,
#          '怎么样': 131,
#          '近日': 4490,
#          '型号': 222,
#          'FS8016': 1,
#          '神秘': 390,
#          '悄然': 283,
#          'GeekBench': 1,
#          '分库': 16,
#          '相关': 11730,
#          '机子': 5,
#          '并非': 1034,
#          '定位': 1107,
#          '所': 6083,
#          '660': 23,
#          '配备': 486,
#          '4GB': 14,
#          '内存': 75,
#          '最受': 187,
#          '瞩目': 124,
#          '芯片': 569,
#          '之一': 5815,
#          '采用': 1965,
#          '14': 8332,
#          '纳米': 145,
#          '工艺': 765,
#          '八个': 106,
#          'Kryo': 1,
#          '260': 98,
#          '设计': 5724,
#          'Adreno': 1,
#          '512': 15,
#          'X12': 1,
#          'LTE': 26,
#          '调制解调器': 7,
#          '当前': 3000,
#          '市面上': 85,
#          '只有': 3515,
#          '上市': 1794,
#          '销售': 3842,
#          'OPPO': 49,
#          'R11': 8,
#          '核新能': 1,
#          '820': 22,
#          '强': 2276,
#          '单核': 6,
#          '改进': 609,
#          '明显': 3638,
#          '所以': 2380,
#          '放在': 740,
#          '变成': 1264,
#          '高端': 1602,
#          '机': 562,
#          '不过': 4040,
#          '签署': 2479,
#          '排他性': 19,
#          '协议': 4190,
#          '独占': 27,
#          '两三个': 53,
#          '时间': 11045,
#          '既然': 182,
#          '测试': 1411,
#          '说明': 1261,
#          '只要': 1579,
#          '时期': 1904,
#          '过': 5974,
#          '新品': 646,
#          '之前': 2488,
#          '曝光': 746,
#          '渲染': 62,
#          '图': 1336,
#          '竞争': 1484,
#          '优势': 4265,
#          ...})

# %%
words_count.most_common(10)
# Out:
# [('的', 703820),
#  ('在', 264633),
#  ('月', 189525),
#  ('日', 169920),
#  ('新华社', 142462),
#  ('和', 134220),
#  ('年', 123531),
#  ('了', 121904),
#  ('是', 100288),
#  ('１', 88187)]

# %%
frequences = [f for w ,f in words_count.most_common(100)]

# %%
len(frequences)
# Out:
# 100

# %%
x = [i for i in range(len(frequences[:100]))]

# %%
len(frequences)
# Out:
# 100

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(x,frequences)

# %%
import numpy as np

# %%
plt.plot(x,np.log(frequences))

# %%
frequences_all = [f for w,f in words_count.most_common()]

# %%
frequences_sum = sum (frequences_all)

# %%
frequences_sum
# Out:
# 17221785

# %%
1 / frequences_sum
# Out:
# 5.8065990255946174e-08

# %%
def get_prob(word):
    esp = 1 / frequences_sum
    if word in words_count:
        return words_count[word] / frequences_sum
    else:
        return esp

# %%
get_prob('我们在一起了')
# Out:
# 5.8065990255946174e-08

# %%
get_prob('的')
# Out:
# 0.04086800526194004

# %%
def product(numbers):
    return reduce(lambda n1 , n2:n1*n2,numbers)

# %%
product([1,2,3,4,10])
# Out:
# 240

# %%
def language_model_one_gram(string):
    words = cut(string)
    return product([get_prob(w) for w in words])

# %%
language_model_one_gram('一个掉在了民房上')
# Out:
# 7.149551679191113e-20

# %%
sentance = """
这是一个比较正常的句子
这个一个比较罕见的句子
小明毕业于清华大学
小明毕业于秦华大学
""".split()

# %%
for s in sentance:
    print(s,language_model_one_gram(s))
# Out:
# 这是一个比较正常的句子 7.429984647015532e-22
# 这个一个比较罕见的句子 1.7566783516469408e-22
# 小明毕业于清华大学 3.039960976514903e-18
# 小明毕业于秦华大学 5.813337476916057e-24

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "我去吃火锅，今晚 今晚我去吃火锅"
]
for s in need_compared:
    s1 ,s2 = s.split()
    p1 ,p2 = language_model_one_gram(s1),language_model_one_gram(s2)
    better = s1 if p1 > p2 else s2
    
    print ('{}is more possible'.format(better))
    print ('-'*4 + '{} with probility {}'.format(s1,p1))
    print ('-'*4 + '{} with probility {}'.format(s2,p2))
# Out:
# 明天晚上请你吃大餐，我们一起吃苹果is more possible
# ----今天晚上请你吃大餐，我们一起吃日料 with probility 6.279484454158278e-50
# ----明天晚上请你吃大餐，我们一起吃苹果 with probility 5.1533768284792506e-48
# 真是一只好看的小猫is more possible
# ----真事一只好看的小猫 with probility 2.873219522813593e-25
# ----真是一只好看的小猫 with probility 1.0935351206452033e-21
# 今晚我去吃火锅is more possible
# ----我去吃火锅，今晚 with probility 6.876097222574346e-26
# ----今晚我去吃火锅 with probility 1.1841866800627252e-18

# %% [markdown]
# ## 2-Gram

# %% [markdown]
# $$ Pr(S) = Pr(w_1\cdot w_2 \cdots w_n) \sim Pr(w_1) \cdot Pr(w_2 | w_1) \cdots Pr(w_n | w_{n-1})$$

# %% [markdown]
# $$ Pr(w_2 | w_1) = Pr(w_1 \cdot w_2) \mid Pr(w_1) $$

# %%
valid_tokens = [str(t) for t in valida_tokens]

# %%
valid_tokens
# Out:
# ['此外',
#  '自',
#  '本周',
#  '6',
#  '月',
#  '12',
#  '日',
#  '起',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  '含',
#  '开发',
#  '版',
#  '体验版',
#  '内测',
#  '稳定版',
#  '暂不受',
#  '影响',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI',
#  '9',
#  '的',
#  '研发',
#  '之中',
#  'MIUI',
#  '8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  '距今已有',
#  '一年',
#  '有余',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  '当然',
#  '关于',
#  'MIUI',
#  '9',
#  '的',
#  '确切',
#  '信息',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows',
#  '10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
#  '高通',
#  '强调',
#  '不会',
#  '因为',
#  '只',
#  '考虑',
#  '性能',
#  '而',
#  '去',
#  '屏蔽掉',
#  '小',
#  '核心',
#  '相反',
#  '他们',
#  '正',
#  '联手',
#  '微软',
#  '找到',
#  '一种',
#  '适合',
#  '桌面',
#  '平台',
#  '的',
#  '兼顾',
#  '性能',
#  '和',
#  '功耗',
#  '的',
#  '完美',
#  '方案',
#  '报道',
#  '称',
#  '微软',
#  '已经',
#  '拿到',
#  '了',
#  '一些',
#  '新',
#  '的',
#  '源码',
#  '以便',
#  'Windows',
#  '10',
#  '更好',
#  '地',
#  '理解',
#  'big',
#  'little',
#  '架构',
#  '资料',
#  '显示',
#  '骁龙',
#  '835',
#  '作为',
#  '一款',
#  '集成',
#  '了',
#  'CPU',
#  'GPU',
#  '基带',
#  '蓝牙',
#  'Wi',
#  'Fi',
#  '的',
#  'SoC',
#  '比',
#  '传统',
#  '的',
#  'Wintel',
#  '方案',
#  '可以',
#  '节省',
#  '至少',
#  '30',
#  '的',
#  'PCB',
#  '空间',
#  '按计划',
#  '今年',
#  'Q4',
#  '华硕',
#  '惠普',
#  '联想',
#  '将',
#  '首发',
#  '骁龙',
#  '835',
#  'Win10',
#  '电脑',
#  '预计',
#  '均',
#  '是',
#  '二合一',
#  '形态',
#  '的',
#  '产品',
#  '当然',
#  '高通',
#  '骁龙',
#  '只是',
#  '个',
#  '开始',
#  '未来',
#  '也许',
#  '还',
#  '能',
#  '见到',
#  '三星',
#  'Exynos',
#  '联发科',
#  '华为',
#  '麒麟',
#  '小米',
#  '澎湃',
#  '等',
#  '进入',
#  'Windows',
#  '10',
#  '桌面',
#  '平台',
#  '此前',
#  '的',
#  '一加',
#  '3T',
#  '搭载',
#  '的',
#  '是',
#  '3400mAh',
#  '电池',
#  'DashCharge',
#  '快充',
#  '规格',
#  '为',
#  '5V',
#  '4A',
#  '至于',
#  '电池',
#  '缩水',
#  '可能',
#  '与',
#  '刘作',
#  '虎',
#  '所说',
#  '一加',
#  '手机',
#  '5',
#  '要',
#  '做',
#  '市面',
#  '最',
#  '轻薄',
#  '大屏',
#  '旗舰',
#  '的',
#  '设定',
#  '有关',
#  '按照',
#  '目前',
#  '掌握',
#  '的',
#  '资料',
#  '一加',
#  '手机',
#  '5',
#  '拥有',
#  '5',
#  '5',
#  '寸',
#  '1080P',
#  '三星',
#  'AMOLED',
#  '显示屏',
#  '6G',
#  '8GB',
#  'RAM',
#  '64GB',
#  '128GB',
#  'ROM',
#  '双',
#  '1600',
#  '万',
#  '摄像头',
#  '备货',
#  '量',
#  '惊喜',
#  '根据',
#  '京东',
#  '泄露',
#  '的',
#  '信息',
#  '一加',
#  '5',
#  '起',
#  '售价',
#  '是',
#  'xx99',
#  '元',
#  '应该',
#  '是',
#  '在',
#  '2799',
#  '2899',
#  '2999',
#  '中',
#  '的',
#  '某个',
#  '这是',
#  '6',
#  '月',
#  '18',
#  '日',
#  '在',
#  '葡萄牙',
#  '中部',
#  '大',
#  '佩德罗',
#  '冈',
#  '地区',
#  '拍摄',
#  '的',
#  '被',
#  '森林',
#  '大火',
#  '烧毁',
#  '的',
#  '汽车',
#  '新华社',
#  '记者',
#  '张立云',
#  '摄原',
#  '标题',
#  '44',
#  '岁',
#  '女子',
#  '跑',
#  '深圳',
#  '约会',
#  '网友',
#  '被',
#  '拒',
#  '暴雨',
#  '中',
#  '裸身',
#  '奔走',
#  '深圳',
#  '交警',
#  '微博称',
#  '昨日',
#  '清晨',
#  '交警',
#  '发现',
#  '有',
#  '一',
#  '女子',
#  '赤裸',
#  '上身',
#  '行走',
#  '在',
#  '南坪',
#  '快速',
#  '上',
#  '期间',
#  '还',
#  '起',
#  '了',
#  '轻生',
#  '年头',
#  '一辅警',
#  '发现',
#  '后',
#  '赶紧',
#  '为',
#  '其',
#  '披上',
#  '黄衣',
#  '并',
#  '一路',
#  '劝说',
#  '她',
#  '那么',
#  '事发',
#  '时',
#  '到底',
#  '都',
#  '发生',
#  '了',
#  '些',
#  '什么',
#  '呢',
#  '南',
#  '都',
#  '记者',
#  '带',
#  '您',
#  '一起',
#  '还原',
#  '现场',
#  '南',
#  '都',
#  '记者',
#  '在',
#  '龙岗',
#  '大队',
#  '坂田',
#  '中队',
#  '见到',
#  '了',
#  '辅警',
#  '刘青',
#  '发现',
#  '女生',
#  '的',
#  '辅警',
#  '一位',
#  '外表',
#  '高大',
#  '帅气',
#  '说话',
#  '略带',
#  '些',
#  '腼腆',
#  '的',
#  '90',
#  '后',
#  '青年',
#  '刘青',
#  '介绍',
#  '6',
#  '月',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '36',
#  '分',
#  '他',
#  '正在',
#  '环城',
#  '南路',
#  '附近',
#  '值勤',
#  '接到',
#  '中队',
#  '关于',
#  '一位',
#  '女子',
#  '裸身',
#  '进入',
#  '机动车',
#  '可能',
#  '有',
#  '危险',
#  '的',
#  '警情',
#  '随后',
#  '骑着',
#  '小',
#  '铁骑',
#  '开始',
#  '沿路',
#  '寻找',
#  '大概',
#  '花',
#  '了',
#  '十多分钟',
#  '在',
#  '南坪',
#  '大道',
#  '坂田',
#  '出口',
#  '往',
#  '龙岗',
#  '方向',
#  '的',
#  '逆行',
#  '辅道',
#  '上',
#  '发现',
#  '该',
#  '女子',
#  '女子',
#  '身上',
#  '一丝不挂',
#  '地逆',
#  '车流',
#  '而行',
#  '时',
#  '走时',
#  '停',
#  '时',
#  '坐',
#  '时',
#  '躺',
#  '险象环生',
#  '刘青停',
#  '好',
#  '小',
#  '铁骑',
#  '和',
#  '另外',
#  '一名',
#  '巡防',
#  '员',
#  '追',
#  '了',
#  '上去',
#  '发现',
#  '女子',
#  '的',
#  '情绪',
#  '很',
#  '低落',
#  '话',
#  '不',
#  '多',
#  '刘青',
#  '尝试',
#  '和',
#  '女子',
#  '交流',
#  '劝说',
#  '女子',
#  '离开',
#  '可',
#  '女子',
#  '并',
#  '不',
#  '愿意',
#  '接受',
#  '继续',
#  '缓慢',
#  '地往',
#  '南坪',
#  '快速路',
#  '的',
#  '主干道',
#  '上',
#  '走',
#  '去',
#  '此时',
#  '路边',
#  '上',
#  '已经',
#  '聚集',
#  '了',
#  '很',
#  '市民',
#  '围观',
#  '为了',
#  '不',
#  '刺激',
#  '女子',
#  '的',
#  '情绪',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '一边',
#  '盯',
#  '着',
#  '女子',
#  '一边',
#  '驱赶',
#  '着',
#  '围观',
#  '的',
#  '群众',
#  '现场',
#  '还原',
#  '从',
#  '警方',
#  '提供',
#  '的',
#  '一份',
#  '视频',
#  '了解',
#  '到',
#  '16',
#  '日',
#  '早上',
#  '7',
#  '时',
#  '25',
#  '分',
#  '女子',
#  '出现',
#  '在',
#  '坂雪岗',
#  '大道',
#  '与',
#  '环城',
#  '南路',
#  '的',
#  '监控',
#  '视频',
#  '中',
#  '此时',
#  '女子',
#  '还',
#  '穿着',
#  '白色',
#  '的',
#  '内裤',
#  '正',
#  '沿着',
#  '坂雪岗',
#  '大道',
#  '往',
#  '南坪',
#  '快速',
#  '的',
#  '方向',
#  '缓慢',
#  '地',
#  '走',
#  '着',
#  '当时',
#  '正值',
#  '上班',
#  '高峰期',
#  '十字路口',
#  '的',
#  '车流',
#  '已经',
#  '排起',
#  '了',
#  '长队',
#  '当',
#  '女子',
#  '出现',
#  '时',
#  '路上',
#  '的',
#  '市民',
#  '纷纷',
#  '驻足',
#  '观望',
#  '不少',
#  '车辆',
#  '也',
#  '放慢',
#  '了',
#  '速度',
#  '但',
#  '女子',
#  '并',
#  '不',
#  '为',
#  '市民',
#  '观望',
#  '停下',
#  '脚步',
#  '依然',
#  '缓慢',
#  '走',
#  '着',
#  '当',
#  '女子',
#  '行进',
#  '到',
#  '十字路口',
#  '中间',
#  '时',
#  '一辆',
#  '大',
#  '货车',
#  '挡住',
#  '了',
#  '镜头',
#  '但是',
#  '当',
#  '女子',
#  '再次出现',
#  '镜头',
#  '时',
#  '可以',
#  '发现',
#  '女子',
#  '已经',
#  '没',
#  '穿',
#  '内裤',
#  '了',
#  '全身',
#  '裸露',
#  '继续',
#  '朝着',
#  '南坪',
#  '快速',
#  '方向',
#  '走',
#  '去',
#  '记者',
#  '发现',
#  '视频',
#  '中',
#  '女子',
#  '周围',
#  '并',
#  '没有',
#  '人',
#  '尾随',
#  '或者',
#  '上前',
#  '劝止',
#  '的',
#  '市民',
#  '一',
#  '大清早',
#  '路上',
#  '看到',
#  '这样',
#  '的',
#  '情况',
#  '恐怕',
#  '大家',
#  '都',
#  '没',
#  '办法',
#  '淡定',
#  '面对',
#  '这一',
#  '情况',
#  '刘青',
#  '表示',
#  '一',
#  '开始',
#  '根本',
#  '不敢',
#  '看',
#  '她',
#  '心里',
#  '挺',
#  '别扭',
#  '感觉',
#  '很',
#  '尴尬',
#  '但',
#  '当',
#  '刘青',
#  '跟随',
#  '女子',
#  '上',
#  '了',
#  '南坪',
#  '快速路',
#  '主干道',
#  '时',
#  '女子',
#  '作出',
#  '了',
#  '让',
#  '人',
#  '意想不到',
#  '的',
#  '举动',
#  '她',
#  '突然',
#  '靠近',
#  '护栏',
#  '要',
#  '从',
#  '上面',
#  '跳下去',
#  '刘青',
#  '赶忙',
#  '冲上去',
#  '拉住',
#  '了',
#  '女子',
#  '的',
#  '手',
#  '将',
#  '其',
#  '控制',
#  '住',
#  '并',
#  '远离',
#  '护栏',
#  '碍于',
#  '女子',
#  '没有',
#  '穿衣服',
#  '刘青递',
#  '上',
#  '衣服',
#  '女子',
#  '没',
#  '接受',
#  '还',
#  '把',
#  '衣服',
#  '扔',
#  '到',
#  '排水沟',
#  '里',
#  '继续',
#  '往前走',
#  '没',
#  '办法',
#  '刘青',
#  '只能',
#  '紧紧',
#  '拉',
#  '着',
#  '她',
#  '的',
#  '一只',
#  '手',
#  '跟',
#  '在',
#  '后面',
#  '刘青',
#  '一路上',
#  '耐心',
#  '地',
#  '开导',
#  '安慰',
#  '她',
#  '但',
#  '只',
#  '听到',
#  '她',
#  '不断',
#  '地',
#  '重复',
#  '着',
#  '一句',
#  '话',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '的',
#  '期间',
#  '她',
#  '还',
#  '不时',
#  '试图',
#  '挣脱',
#  '刘青',
#  '的',
#  '手要',
#  '冲向',
#  '护栏',
#  '往下跳',
#  '就',
#  '这样',
#  '我',
#  '被',
#  '牵',
#  '着',
#  '走',
#  '了',
#  '大概',
#  '十多分钟',
#  '天',
#  '突然',
#  '下起',
#  '了',
#  '大暴雨',
#  '雨大',
#  '的',
#  '连',
#  '眼睛',
#  '都',
#  '睁不开',
#  '刘青',
#  '继续',
#  '说',
#  '着',
#  '瞬间',
#  '他们',
#  '就',
#  '被',
#  '雨',
#  '透',
#  '了',
#  '但',
#  '女子',
#  '依然',
#  '不',
#  '愿意',
#  '接受',
#  '刘青',
#  '的',
#  '帮助',
#  '就',
#  '继续',
#  '冒',
#  '着',
#  '大雨',
#  '往前走',
#  '大概',
#  '走',
#  '了',
#  '有',
#  '四十分钟',
#  '吧',
#  '女子',
#  '突然',
#  '停下',
#  '来说',
#  '我',
#  '想',
#  '回家',
#  '了',
#  '然后',
#  '女子',
#  '也',
#  '接受',
#  '了',
#  '刘青',
#  '递过来',
#  '的',
#  '小',
#  '黄衣',
#  '就',
#  '出现',
#  '了',
#  '深圳',
#  '微博上',
#  '的',
#  '照片',
#  '女子',
#  '披着',
#  '小',
#  '黄衣',
#  '刘青',
#  '小心翼翼',
#  '地',
#  '在',
#  '旁边',
#  '走',
#  '着',
#  '的',
#  '场景',
#  '从',
#  '南平',
#  '快速',
#  '下来',
#  '后',
#  '刘青',
#  '和',
#  '巡防',
#  '员',
#  '将',
#  '女子',
#  '带到',
#  '了',
#  '附近',
#  '的',
#  '坂田',
#  '派出所',
#  '那',
#  '姑娘',
#  '到底',
#  '是',
#  '遭遇',
#  '了',
#  '什么样',
#  '的',
#  '事情',
#  '才',
#  '会',
#  '说',
#  '要是',
#  '你',
#  '也',
#  '遭遇',
#  '我',
#  '的',
#  '事',
#  '你',
#  '也',
#  '会',
#  '这样',
#  '据',
#  '警方',
#  '透露',
#  '该',
#  '女子',
#  '姓',
#  '陈',
#  '系',
#  '湖北',
#  '人',
#  '今年',
#  '44',
#  '岁',
#  '据',
#  '家属',
#  '反映',
#  '其有',
#  '精神病',
#  '史',
#  '三天',
#  '前',
#  ...]

# %%
all_2_grams_words = [''.join(valid_tokens[i:i+2]) for i in range(len(valid_tokens[:-2]))]

# %%
all_2_grams_words
# Out:
# ['此外自',
#  '自本周',
#  '本周6',
#  '6月',
#  '月12',
#  '12日',
#  '日起',
#  '起除',
#  '除小米',
#  '小米手机',
#  '手机6',
#  '6等',
#  '等15',
#  '15款',
#  '款机型',
#  '机型外',
#  '外其余',
#  '其余机型',
#  '机型已',
#  '已暂停',
#  '暂停更新',
#  '更新发布',
#  '发布含',
#  '含开发',
#  '开发版',
#  '版体验版',
#  '体验版内测',
#  '内测稳定版',
#  '稳定版暂不受',
#  '暂不受影响',
#  '影响以',
#  '以确保',
#  '确保工程师',
#  '工程师可以',
#  '可以集中',
#  '集中全部',
#  '全部精力',
#  '精力进行',
#  '进行系统优化',
#  '系统优化工作',
#  '工作有人',
#  '有人猜测',
#  '猜测这',
#  '这也',
#  '也是',
#  '是将',
#  '将精力',
#  '精力主要',
#  '主要用到',
#  '用到MIUI',
#  'MIUI9',
#  '9的',
#  '的研发',
#  '研发之中',
#  '之中MIUI',
#  'MIUI8',
#  '8去年',
#  '去年5',
#  '5月',
#  '月发布',
#  '发布距今已有',
#  '距今已有一年',
#  '一年有余',
#  '有余也',
#  '也是',
#  '是时候',
#  '时候更新换代',
#  '更新换代了',
#  '了当然',
#  '当然关于',
#  '关于MIUI',
#  'MIUI9',
#  '9的',
#  '的确切',
#  '确切信息',
#  '信息我们',
#  '我们还是',
#  '还是等待',
#  '等待官方消息',
#  '官方消息骁龙',
#  '骁龙835',
#  '835作为',
#  '作为唯一',
#  '唯一通过',
#  '通过Windows',
#  'Windows10',
#  '10桌面',
#  '桌面平台',
#  '平台认证',
#  '认证的',
#  '的ARM',
#  'ARM处理器',
#  '处理器高通',
#  '高通强调',
#  '强调不会',
#  '不会因为',
#  '因为只',
#  '只考虑',
#  '考虑性能',
#  '性能而',
#  '而去',
#  '去屏蔽掉',
#  '屏蔽掉小',
#  '小核心',
#  '核心相反',
#  '相反他们',
#  '他们正',
#  '正联手',
#  '联手微软',
#  '微软找到',
#  '找到一种',
#  '一种适合',
#  '适合桌面',
#  '桌面平台',
#  '平台的',
#  '的兼顾',
#  '兼顾性能',
#  '性能和',
#  '和功耗',
#  '功耗的',
#  '的完美',
#  '完美方案',
#  '方案报道',
#  '报道称',
#  '称微软',
#  '微软已经',
#  '已经拿到',
#  '拿到了',
#  '了一些',
#  '一些新',
#  '新的',
#  '的源码',
#  '源码以便',
#  '以便Windows',
#  'Windows10',
#  '10更好',
#  '更好地',
#  '地理解',
#  '理解big',
#  'biglittle',
#  'little架构',
#  '架构资料',
#  '资料显示',
#  '显示骁龙',
#  '骁龙835',
#  '835作为',
#  '作为一款',
#  '一款集成',
#  '集成了',
#  '了CPU',
#  'CPUGPU',
#  'GPU基带',
#  '基带蓝牙',
#  '蓝牙Wi',
#  'WiFi',
#  'Fi的',
#  '的SoC',
#  'SoC比',
#  '比传统',
#  '传统的',
#  '的Wintel',
#  'Wintel方案',
#  '方案可以',
#  '可以节省',
#  '节省至少',
#  '至少30',
#  '30的',
#  '的PCB',
#  'PCB空间',
#  '空间按计划',
#  '按计划今年',
#  '今年Q4',
#  'Q4华硕',
#  '华硕惠普',
#  '惠普联想',
#  '联想将',
#  '将首发',
#  '首发骁龙',
#  '骁龙835',
#  '835Win10',
#  'Win10电脑',
#  '电脑预计',
#  '预计均',
#  '均是',
#  '是二合一',
#  '二合一形态',
#  '形态的',
#  '的产品',
#  '产品当然',
#  '当然高通',
#  '高通骁龙',
#  '骁龙只是',
#  '只是个',
#  '个开始',
#  '开始未来',
#  '未来也许',
#  '也许还',
#  '还能',
#  '能见到',
#  '见到三星',
#  '三星Exynos',
#  'Exynos联发科',
#  '联发科华为',
#  '华为麒麟',
#  '麒麟小米',
#  '小米澎湃',
#  '澎湃等',
#  '等进入',
#  '进入Windows',
#  'Windows10',
#  '10桌面',
#  '桌面平台',
#  '平台此前',
#  '此前的',
#  '的一加',
#  '一加3T',
#  '3T搭载',
#  '搭载的',
#  '的是',
#  '是3400mAh',
#  '3400mAh电池',
#  '电池DashCharge',
#  'DashCharge快充',
#  '快充规格',
#  '规格为',
#  '为5V',
#  '5V4A',
#  '4A至于',
#  '至于电池',
#  '电池缩水',
#  '缩水可能',
#  '可能与',
#  '与刘作',
#  '刘作虎',
#  '虎所说',
#  '所说一加',
#  '一加手机',
#  '手机5',
#  '5要',
#  '要做',
#  '做市面',
#  '市面最',
#  '最轻薄',
#  '轻薄大屏',
#  '大屏旗舰',
#  '旗舰的',
#  '的设定',
#  '设定有关',
#  '有关按照',
#  '按照目前',
#  '目前掌握',
#  '掌握的',
#  '的资料',
#  '资料一加',
#  '一加手机',
#  '手机5',
#  '5拥有',
#  '拥有5',
#  '55',
#  '5寸',
#  '寸1080P',
#  '1080P三星',
#  '三星AMOLED',
#  'AMOLED显示屏',
#  '显示屏6G',
#  '6G8GB',
#  '8GBRAM',
#  'RAM64GB',
#  '64GB128GB',
#  '128GBROM',
#  'ROM双',
#  '双1600',
#  '1600万',
#  '万摄像头',
#  '摄像头备货',
#  '备货量',
#  '量惊喜',
#  '惊喜根据',
#  '根据京东',
#  '京东泄露',
#  '泄露的',
#  '的信息',
#  '信息一加',
#  '一加5',
#  '5起',
#  '起售价',
#  '售价是',
#  '是xx99',
#  'xx99元',
#  '元应该',
#  '应该是',
#  '是在',
#  '在2799',
#  '27992899',
#  '28992999',
#  '2999中',
#  '中的',
#  '的某个',
#  '某个这是',
#  '这是6',
#  '6月',
#  '月18',
#  '18日',
#  '日在',
#  '在葡萄牙',
#  '葡萄牙中部',
#  '中部大',
#  '大佩德罗',
#  '佩德罗冈',
#  '冈地区',
#  '地区拍摄',
#  '拍摄的',
#  '的被',
#  '被森林',
#  '森林大火',
#  '大火烧毁',
#  '烧毁的',
#  '的汽车',
#  '汽车新华社',
#  '新华社记者',
#  '记者张立云',
#  '张立云摄原',
#  '摄原标题',
#  '标题44',
#  '44岁',
#  '岁女子',
#  '女子跑',
#  '跑深圳',
#  '深圳约会',
#  '约会网友',
#  '网友被',
#  '被拒',
#  '拒暴雨',
#  '暴雨中',
#  '中裸身',
#  '裸身奔走',
#  '奔走深圳',
#  '深圳交警',
#  '交警微博称',
#  '微博称昨日',
#  '昨日清晨',
#  '清晨交警',
#  '交警发现',
#  '发现有',
#  '有一',
#  '一女子',
#  '女子赤裸',
#  '赤裸上身',
#  '上身行走',
#  '行走在',
#  '在南坪',
#  '南坪快速',
#  '快速上',
#  '上期间',
#  '期间还',
#  '还起',
#  '起了',
#  '了轻生',
#  '轻生年头',
#  '年头一辅警',
#  '一辅警发现',
#  '发现后',
#  '后赶紧',
#  '赶紧为',
#  '为其',
#  '其披上',
#  '披上黄衣',
#  '黄衣并',
#  '并一路',
#  '一路劝说',
#  '劝说她',
#  '她那么',
#  '那么事发',
#  '事发时',
#  '时到底',
#  '到底都',
#  '都发生',
#  '发生了',
#  '了些',
#  '些什么',
#  '什么呢',
#  '呢南',
#  '南都',
#  '都记者',
#  '记者带',
#  '带您',
#  '您一起',
#  '一起还原',
#  '还原现场',
#  '现场南',
#  '南都',
#  '都记者',
#  '记者在',
#  '在龙岗',
#  '龙岗大队',
#  '大队坂田',
#  '坂田中队',
#  '中队见到',
#  '见到了',
#  '了辅警',
#  '辅警刘青',
#  '刘青发现',
#  '发现女生',
#  '女生的',
#  '的辅警',
#  '辅警一位',
#  '一位外表',
#  '外表高大',
#  '高大帅气',
#  '帅气说话',
#  '说话略带',
#  '略带些',
#  '些腼腆',
#  '腼腆的',
#  '的90',
#  '90后',
#  '后青年',
#  '青年刘青',
#  '刘青介绍',
#  '介绍6',
#  '6月',
#  '月16',
#  '16日',
#  '日早上',
#  '早上7',
#  '7时',
#  '时36',
#  '36分',
#  '分他',
#  '他正在',
#  '正在环城',
#  '环城南路',
#  '南路附近',
#  '附近值勤',
#  '值勤接到',
#  '接到中队',
#  '中队关于',
#  '关于一位',
#  '一位女子',
#  '女子裸身',
#  '裸身进入',
#  '进入机动车',
#  '机动车可能',
#  '可能有',
#  '有危险',
#  '危险的',
#  '的警情',
#  '警情随后',
#  '随后骑着',
#  '骑着小',
#  '小铁骑',
#  '铁骑开始',
#  '开始沿路',
#  '沿路寻找',
#  '寻找大概',
#  '大概花',
#  '花了',
#  '了十多分钟',
#  '十多分钟在',
#  '在南坪',
#  '南坪大道',
#  '大道坂田',
#  '坂田出口',
#  '出口往',
#  '往龙岗',
#  '龙岗方向',
#  '方向的',
#  '的逆行',
#  '逆行辅道',
#  '辅道上',
#  '上发现',
#  '发现该',
#  '该女子',
#  '女子女子',
#  '女子身上',
#  '身上一丝不挂',
#  '一丝不挂地逆',
#  '地逆车流',
#  '车流而行',
#  '而行时',
#  '时走时',
#  '走时停',
#  '停时',
#  '时坐',
#  '坐时',
#  '时躺',
#  '躺险象环生',
#  '险象环生刘青停',
#  '刘青停好',
#  '好小',
#  '小铁骑',
#  '铁骑和',
#  '和另外',
#  '另外一名',
#  '一名巡防',
#  '巡防员',
#  '员追',
#  '追了',
#  '了上去',
#  '上去发现',
#  '发现女子',
#  '女子的',
#  '的情绪',
#  '情绪很',
#  '很低落',
#  '低落话',
#  '话不',
#  '不多',
#  '多刘青',
#  '刘青尝试',
#  '尝试和',
#  '和女子',
#  '女子交流',
#  '交流劝说',
#  '劝说女子',
#  '女子离开',
#  '离开可',
#  '可女子',
#  '女子并',
#  '并不',
#  '不愿意',
#  '愿意接受',
#  '接受继续',
#  '继续缓慢',
#  '缓慢地往',
#  '地往南坪',
#  '南坪快速路',
#  '快速路的',
#  '的主干道',
#  '主干道上',
#  '上走',
#  '走去',
#  '去此时',
#  '此时路边',
#  '路边上',
#  '上已经',
#  '已经聚集',
#  '聚集了',
#  '了很',
#  '很市民',
#  '市民围观',
#  '围观为了',
#  '为了不',
#  '不刺激',
#  '刺激女子',
#  '女子的',
#  '的情绪',
#  '情绪刘青',
#  '刘青和',
#  '和巡防',
#  '巡防员',
#  '员一边',
#  '一边盯',
#  '盯着',
#  '着女子',
#  '女子一边',
#  '一边驱赶',
#  '驱赶着',
#  '着围观',
#  '围观的',
#  '的群众',
#  '群众现场',
#  '现场还原',
#  '还原从',
#  '从警方',
#  '警方提供',
#  '提供的',
#  '的一份',
#  '一份视频',
#  '视频了解',
#  '了解到',
#  '到16',
#  '16日',
#  '日早上',
#  '早上7',
#  '7时',
#  '时25',
#  '25分',
#  '分女子',
#  '女子出现',
#  '出现在',
#  '在坂雪岗',
#  '坂雪岗大道',
#  '大道与',
#  '与环城',
#  '环城南路',
#  '南路的',
#  '的监控',
#  '监控视频',
#  '视频中',
#  '中此时',
#  '此时女子',
#  '女子还',
#  '还穿着',
#  '穿着白色',
#  '白色的',
#  '的内裤',
#  '内裤正',
#  '正沿着',
#  '沿着坂雪岗',
#  '坂雪岗大道',
#  '大道往',
#  '往南坪',
#  '南坪快速',
#  '快速的',
#  '的方向',
#  '方向缓慢',
#  '缓慢地',
#  '地走',
#  '走着',
#  '着当时',
#  '当时正值',
#  '正值上班',
#  '上班高峰期',
#  '高峰期十字路口',
#  '十字路口的',
#  '的车流',
#  '车流已经',
#  '已经排起',
#  '排起了',
#  '了长队',
#  '长队当',
#  '当女子',
#  '女子出现',
#  '出现时',
#  '时路上',
#  '路上的',
#  '的市民',
#  '市民纷纷',
#  '纷纷驻足',
#  '驻足观望',
#  '观望不少',
#  '不少车辆',
#  '车辆也',
#  '也放慢',
#  '放慢了',
#  '了速度',
#  '速度但',
#  '但女子',
#  '女子并',
#  '并不',
#  '不为',
#  '为市民',
#  '市民观望',
#  '观望停下',
#  '停下脚步',
#  '脚步依然',
#  '依然缓慢',
#  '缓慢走',
#  '走着',
#  '着当',
#  '当女子',
#  '女子行进',
#  '行进到',
#  '到十字路口',
#  '十字路口中间',
#  '中间时',
#  '时一辆',
#  '一辆大',
#  '大货车',
#  '货车挡住',
#  '挡住了',
#  '了镜头',
#  '镜头但是',
#  '但是当',
#  '当女子',
#  '女子再次出现',
#  '再次出现镜头',
#  '镜头时',
#  '时可以',
#  '可以发现',
#  '发现女子',
#  '女子已经',
#  '已经没',
#  '没穿',
#  '穿内裤',
#  '内裤了',
#  '了全身',
#  '全身裸露',
#  '裸露继续',
#  '继续朝着',
#  '朝着南坪',
#  '南坪快速',
#  '快速方向',
#  '方向走',
#  '走去',
#  '去记者',
#  '记者发现',
#  '发现视频',
#  '视频中',
#  '中女子',
#  '女子周围',
#  '周围并',
#  '并没有',
#  '没有人',
#  '人尾随',
#  '尾随或者',
#  '或者上前',
#  '上前劝止',
#  '劝止的',
#  '的市民',
#  '市民一',
#  '一大清早',
#  '大清早路上',
#  '路上看到',
#  '看到这样',
#  '这样的',
#  '的情况',
#  '情况恐怕',
#  '恐怕大家',
#  '大家都',
#  '都没',
#  '没办法',
#  '办法淡定',
#  '淡定面对',
#  '面对这一',
#  '这一情况',
#  '情况刘青',
#  '刘青表示',
#  '表示一',
#  '一开始',
#  '开始根本',
#  '根本不敢',
#  '不敢看',
#  '看她',
#  '她心里',
#  '心里挺',
#  '挺别扭',
#  '别扭感觉',
#  '感觉很',
#  '很尴尬',
#  '尴尬但',
#  '但当',
#  '当刘青',
#  '刘青跟随',
#  '跟随女子',
#  '女子上',
#  '上了',
#  '了南坪',
#  '南坪快速路',
#  '快速路主干道',
#  '主干道时',
#  '时女子',
#  '女子作出',
#  '作出了',
#  '了让',
#  '让人',
#  '人意想不到',
#  '意想不到的',
#  '的举动',
#  '举动她',
#  '她突然',
#  '突然靠近',
#  '靠近护栏',
#  '护栏要',
#  '要从',
#  '从上面',
#  '上面跳下去',
#  '跳下去刘青',
#  '刘青赶忙',
#  '赶忙冲上去',
#  '冲上去拉住',
#  '拉住了',
#  '了女子',
#  '女子的',
#  '的手',
#  '手将',
#  '将其',
#  '其控制',
#  '控制住',
#  '住并',
#  '并远离',
#  '远离护栏',
#  '护栏碍于',
#  '碍于女子',
#  '女子没有',
#  '没有穿衣服',
#  '穿衣服刘青递',
#  '刘青递上',
#  '上衣服',
#  '衣服女子',
#  '女子没',
#  '没接受',
#  '接受还',
#  '还把',
#  '把衣服',
#  '衣服扔',
#  '扔到',
#  '到排水沟',
#  '排水沟里',
#  '里继续',
#  '继续往前走',
#  '往前走没',
#  '没办法',
#  '办法刘青',
#  '刘青只能',
#  '只能紧紧',
#  '紧紧拉',
#  '拉着',
#  '着她',
#  '她的',
#  '的一只',
#  '一只手',
#  '手跟',
#  '跟在',
#  '在后面',
#  '后面刘青',
#  '刘青一路上',
#  '一路上耐心',
#  '耐心地',
#  '地开导',
#  '开导安慰',
#  '安慰她',
#  '她但',
#  '但只',
#  '只听到',
#  '听到她',
#  '她不断',
#  '不断地',
#  '地重复',
#  '重复着',
#  '着一句',
#  '一句话',
#  '话要是',
#  '要是你',
#  '你也',
#  '也遭遇',
#  '遭遇我',
#  '我的',
#  '的事',
#  '事你',
#  '你也',
#  '也会',
#  '会这样',
#  '这样的',
#  '的期间',
#  '期间她',
#  '她还',
#  '还不时',
#  '不时试图',
#  '试图挣脱',
#  '挣脱刘青',
#  '刘青的',
#  '的手要',
#  '手要冲向',
#  '冲向护栏',
#  '护栏往下跳',
#  '往下跳就',
#  '就这样',
#  '这样我',
#  '我被',
#  '被牵',
#  '牵着',
#  '着走',
#  '走了',
#  '了大概',
#  '大概十多分钟',
#  '十多分钟天',
#  '天突然',
#  '突然下起',
#  '下起了',
#  '了大暴雨',
#  '大暴雨雨大',
#  '雨大的',
#  '的连',
#  '连眼睛',
#  '眼睛都',
#  '都睁不开',
#  '睁不开刘青',
#  '刘青继续',
#  '继续说',
#  '说着',
#  '着瞬间',
#  '瞬间他们',
#  '他们就',
#  '就被',
#  '被雨',
#  '雨透',
#  '透了',
#  '了但',
#  '但女子',
#  '女子依然',
#  '依然不',
#  '不愿意',
#  '愿意接受',
#  '接受刘青',
#  '刘青的',
#  '的帮助',
#  '帮助就',
#  '就继续',
#  '继续冒',
#  '冒着',
#  '着大雨',
#  '大雨往前走',
#  '往前走大概',
#  '大概走',
#  '走了',
#  '了有',
#  '有四十分钟',
#  '四十分钟吧',
#  '吧女子',
#  '女子突然',
#  '突然停下',
#  '停下来说',
#  '来说我',
#  '我想',
#  '想回家',
#  '回家了',
#  '了然后',
#  '然后女子',
#  '女子也',
#  '也接受',
#  '接受了',
#  '了刘青',
#  '刘青递过来',
#  '递过来的',
#  '的小',
#  '小黄衣',
#  '黄衣就',
#  '就出现',
#  '出现了',
#  '了深圳',
#  '深圳微博上',
#  '微博上的',
#  '的照片',
#  '照片女子',
#  '女子披着',
#  '披着小',
#  '小黄衣',
#  '黄衣刘青',
#  '刘青小心翼翼',
#  '小心翼翼地',
#  '地在',
#  '在旁边',
#  '旁边走',
#  '走着',
#  '着的',
#  '的场景',
#  '场景从',
#  '从南平',
#  '南平快速',
#  '快速下来',
#  '下来后',
#  '后刘青',
#  '刘青和',
#  '和巡防',
#  '巡防员',
#  '员将',
#  '将女子',
#  '女子带到',
#  '带到了',
#  '了附近',
#  '附近的',
#  '的坂田',
#  '坂田派出所',
#  '派出所那',
#  '那姑娘',
#  '姑娘到底',
#  '到底是',
#  '是遭遇',
#  '遭遇了',
#  '了什么样',
#  '什么样的',
#  '的事情',
#  '事情才',
#  '才会',
#  '会说',
#  '说要是',
#  '要是你',
#  '你也',
#  '也遭遇',
#  '遭遇我',
#  '我的',
#  '的事',
#  '事你',
#  '你也',
#  '也会',
#  '会这样',
#  '这样据',
#  '据警方',
#  '警方透露',
#  '透露该',
#  '该女子',
#  '女子姓',
#  '姓陈',
#  '陈系',
#  '系湖北',
#  '湖北人',
#  '人今年',
#  '今年44',
#  '44岁',
#  '岁据',
#  '据家属',
#  '家属反映',
#  '反映其有',
#  '其有精神病',
#  '精神病史',
#  '史三天',
#  '三天前',
#  '前陈某',
#  ...]

# %%
_2_gram_sum = len(all_2_grams_words)
_2_gram_counter = Counter(all_2_grams_words)

def get_combination_prob(w1,w2):
    if w1 + w2 in _2_gram_counter: return _2_gram_counter[w1+w2] / _2_gram_sum
    else:
        return 1 / _2_gram_sum

# %%
_2_gram_sum
# Out:
# 17221783

# %%
_2_gram_counter
# Out:
# Counter({'此外自': 7,
#          '自本周': 2,
#          '本周6': 3,
#          '6月': 17309,
#          '月12': 4305,
#          '12日': 4228,
#          '日起': 11,
#          '起除': 1,
#          '除小米': 1,
#          '小米手机': 9,
#          '手机6': 1,
#          '6等': 3,
#          '等15': 41,
#          '15款': 5,
#          '款机型': 2,
#          '机型外': 1,
#          '外其余': 50,
#          '其余机型': 1,
#          '机型已': 1,
#          '已暂停': 12,
#          '暂停更新': 1,
#          '更新发布': 1,
#          '发布含': 1,
#          '含开发': 1,
#          '开发版': 1,
#          '版体验版': 1,
#          '体验版内测': 1,
#          '内测稳定版': 1,
#          '稳定版暂不受': 1,
#          '暂不受影响': 1,
#          '影响以': 10,
#          '以确保': 140,
#          '确保工程师': 1,
#          '工程师可以': 1,
#          '可以集中': 5,
#          '集中全部': 1,
#          '全部精力': 10,
#          '精力进行': 1,
#          '进行系统优化': 1,
#          '系统优化工作': 1,
#          '工作有人': 3,
#          '有人猜测': 5,
#          '猜测这': 12,
#          '这也': 1623,
#          '也是': 7122,
#          '是将': 172,
#          '将精力': 12,
#          '精力主要': 1,
#          '主要用到': 1,
#          '用到MIUI': 1,
#          'MIUI9': 2,
#          '9的': 70,
#          '的研发': 320,
#          '研发之中': 2,
#          '之中MIUI': 1,
#          'MIUI8': 1,
#          '8去年': 2,
#          '去年5': 87,
#          '5月': 39814,
#          '月发布': 114,
#          '发布距今已有': 1,
#          '距今已有一年': 1,
#          '一年有余': 3,
#          '有余也': 1,
#          '是时候': 43,
#          '时候更新换代': 1,
#          '更新换代了': 1,
#          '了当然': 16,
#          '当然关于': 1,
#          '关于MIUI': 1,
#          '的确切': 30,
#          '确切信息': 5,
#          '信息我们': 14,
#          '我们还是': 48,
#          '还是等待': 3,
#          '等待官方消息': 1,
#          '官方消息骁龙': 1,
#          '骁龙835': 17,
#          '835作为': 2,
#          '作为唯一': 21,
#          '唯一通过': 6,
#          '通过Windows': 3,
#          'Windows10': 17,
#          '10桌面': 2,
#          '桌面平台': 3,
#          '平台认证': 1,
#          '认证的': 82,
#          '的ARM': 1,
#          'ARM处理器': 1,
#          '处理器高通': 1,
#          '高通强调': 1,
#          '强调不会': 11,
#          '不会因为': 53,
#          '因为只': 3,
#          '只考虑': 22,
#          '考虑性能': 1,
#          '性能而': 1,
#          '而去': 46,
#          '去屏蔽掉': 1,
#          '屏蔽掉小': 1,
#          '小核心': 3,
#          '核心相反': 1,
#          '相反他们': 5,
#          '他们正': 29,
#          '正联手': 2,
#          '联手微软': 1,
#          '微软找到': 1,
#          '找到一种': 14,
#          '一种适合': 1,
#          '适合桌面': 1,
#          '平台的': 402,
#          '的兼顾': 1,
#          '兼顾性能': 1,
#          '性能和': 28,
#          '和功耗': 2,
#          '功耗的': 4,
#          '的完美': 57,
#          '完美方案': 1,
#          '方案报道': 1,
#          '报道称': 1216,
#          '称微软': 2,
#          '微软已经': 2,
#          '已经拿到': 6,
#          '拿到了': 189,
#          '了一些': 564,
#          '一些新': 81,
#          '新的': 4328,
#          '的源码': 1,
#          '源码以便': 1,
#          '以便Windows': 1,
#          '10更好': 1,
#          '更好地': 1067,
#          '地理解': 50,
#          '理解big': 1,
#          'biglittle': 1,
#          'little架构': 1,
#          '架构资料': 1,
#          '资料显示': 203,
#          '显示骁龙': 1,
#          '作为一款': 13,
#          '一款集成': 1,
#          '集成了': 10,
#          '了CPU': 1,
#          'CPUGPU': 1,
#          'GPU基带': 1,
#          '基带蓝牙': 3,
#          '蓝牙Wi': 1,
#          'WiFi': 12,
#          'Fi的': 4,
#          '的SoC': 2,
#          'SoC比': 1,
#          '比传统': 31,
#          '传统的': 810,
#          '的Wintel': 2,
#          'Wintel方案': 1,
#          '方案可以': 5,
#          '可以节省': 9,
#          '节省至少': 1,
#          '至少30': 11,
#          '30的': 96,
#          '的PCB': 1,
#          'PCB空间': 1,
#          '空间按计划': 1,
#          '按计划今年': 1,
#          '今年Q4': 1,
#          'Q4华硕': 1,
#          '华硕惠普': 2,
#          '惠普联想': 1,
#          '联想将': 3,
#          '将首发': 3,
#          '首发骁龙': 2,
#          '835Win10': 1,
#          'Win10电脑': 1,
#          '电脑预计': 1,
#          '预计均': 2,
#          '均是': 116,
#          '是二合一': 1,
#          '二合一形态': 1,
#          '形态的': 36,
#          '的产品': 990,
#          '产品当然': 2,
#          '当然高通': 1,
#          '高通骁龙': 13,
#          '骁龙只是': 1,
#          '只是个': 36,
#          '个开始': 7,
#          '开始未来': 6,
#          '未来也许': 5,
#          '也许还': 5,
#          '还能': 853,
#          '能见到': 24,
#          '见到三星': 1,
#          '三星Exynos': 2,
#          'Exynos联发科': 1,
#          '联发科华为': 2,
#          '华为麒麟': 1,
#          '麒麟小米': 1,
#          '小米澎湃': 1,
#          '澎湃等': 3,
#          '等进入': 6,
#          '进入Windows': 1,
#          '平台此前': 2,
#          '此前的': 198,
#          '的一加': 1,
#          '一加3T': 1,
#          '3T搭载': 1,
#          '搭载的': 36,
#          '的是': 6107,
#          '是3400mAh': 1,
#          '3400mAh电池': 1,
#          '电池DashCharge': 1,
#          'DashCharge快充': 1,
#          '快充规格': 1,
#          '规格为': 5,
#          '为5V': 2,
#          '5V4A': 1,
#          '4A至于': 1,
#          '至于电池': 1,
#          '电池缩水': 1,
#          '缩水可能': 1,
#          '可能与': 118,
#          '与刘作': 1,
#          '刘作虎': 3,
#          '虎所说': 1,
#          '所说一加': 1,
#          '一加手机': 4,
#          '手机5': 6,
#          '5要': 1,
#          '要做': 264,
#          '做市面': 1,
#          '市面最': 1,
#          '最轻薄': 2,
#          '轻薄大屏': 1,
#          '大屏旗舰': 1,
#          '旗舰的': 2,
#          '的设定': 16,
#          '设定有关': 1,
#          '有关按照': 2,
#          '按照目前': 28,
#          '目前掌握': 19,
#          '掌握的': 156,
#          '的资料': 210,
#          '资料一加': 1,
#          '5拥有': 2,
#          '拥有5': 8,
#          '55': 199,
#          '5寸': 5,
#          '寸1080P': 1,
#          '1080P三星': 1,
#          '三星AMOLED': 1,
#          'AMOLED显示屏': 3,
#          '显示屏6G': 1,
#          '6G8GB': 1,
#          '8GBRAM': 2,
#          'RAM64GB': 2,
#          '64GB128GB': 2,
#          '128GBROM': 3,
#          'ROM双': 1,
#          '双1600': 1,
#          '1600万': 8,
#          '万摄像头': 2,
#          '摄像头备货': 1,
#          '备货量': 1,
#          '量惊喜': 1,
#          '惊喜根据': 1,
#          '根据京东': 8,
#          '京东泄露': 1,
#          '泄露的': 56,
#          '的信息': 797,
#          '信息一加': 1,
#          '一加5': 22,
#          '5起': 18,
#          '起售价': 5,
#          '售价是': 4,
#          '是xx99': 1,
#          'xx99元': 1,
#          '元应该': 1,
#          '应该是': 332,
#          '是在': 2791,
#          '在2799': 1,
#          '27992899': 1,
#          '28992999': 1,
#          '2999中': 1,
#          '中的': 5461,
#          '的某个': 25,
#          '某个这是': 1,
#          '这是6': 171,
#          '月18': 4821,
#          '18日': 4881,
#          '日在': 27207,
#          '在葡萄牙': 262,
#          '葡萄牙中部': 9,
#          '中部大': 11,
#          '大佩德罗': 2,
#          '佩德罗冈': 2,
#          '冈地区': 2,
#          '地区拍摄': 23,
#          '拍摄的': 4339,
#          '的被': 70,
#          '被森林': 2,
#          '森林大火': 17,
#          '大火烧毁': 3,
#          '烧毁的': 11,
#          '的汽车': 327,
#          '汽车新华社': 6,
#          '新华社记者': 30864,
#          '记者张立云': 2,
#          '张立云摄原': 1,
#          '摄原标题': 12,
#          '标题44': 1,
#          '44岁': 42,
#          '岁女子': 15,
#          '女子跑': 1,
#          '跑深圳': 1,
#          '深圳约会': 3,
#          '约会网友': 3,
#          '网友被': 3,
#          '被拒': 25,
#          '拒暴雨': 1,
#          '暴雨中': 5,
#          '中裸身': 1,
#          '裸身奔走': 1,
#          '奔走深圳': 1,
#          '深圳交警': 5,
#          '交警微博称': 2,
#          '微博称昨日': 1,
#          '昨日清晨': 1,
#          '清晨交警': 2,
#          '交警发现': 2,
#          '发现有': 142,
#          '有一': 59,
#          '一女子': 24,
#          '女子赤裸': 2,
#          '赤裸上身': 8,
#          '上身行走': 2,
#          '行走在': 114,
#          '在南坪': 7,
#          '南坪快速': 6,
#          '快速上': 4,
#          '上期间': 2,
#          '期间还': 87,
#          '还起': 2,
#          '起了': 262,
#          '了轻生': 6,
#          '轻生年头': 2,
#          '年头一辅警': 2,
#          '一辅警发现': 2,
#          '发现后': 29,
#          '后赶紧': 4,
#          '赶紧为': 3,
#          '为其': 305,
#          '其披上': 2,
#          '披上黄衣': 2,
#          '黄衣并': 2,
#          '并一路': 8,
#          '一路劝说': 2,
#          '劝说她': 2,
#          '她那么': 2,
#          '那么事发': 1,
#          '事发时': 106,
#          '时到底': 1,
#          '到底都': 2,
#          '都发生': 28,
#          '发生了': 504,
#          '了些': 46,
#          '些什么': 19,
#          '什么呢': 47,
#          '呢南': 2,
#          '南都': 26,
#          '都记者': 15,
#          '记者带': 43,
#          '带您': 19,
#          '您一起': 17,
#          '一起还原': 1,
#          '还原现场': 2,
#          '现场南': 1,
#          '记者在': 1125,
#          '在龙岗': 1,
#          '龙岗大队': 2,
#          '大队坂田': 2,
#          '坂田中队': 2,
#          '中队见到': 2,
#          '见到了': 108,
#          '了辅警': 2,
#          '辅警刘青': 2,
#          '刘青发现': 2,
#          '发现女生': 2,
#          '女生的': 30,
#          '的辅警': 6,
#          '辅警一位': 2,
#          '一位外表': 3,
#          '外表高大': 2,
#          '高大帅气': 2,
#          '帅气说话': 2,
#          '说话略带': 2,
#          '略带些': 2,
#          '些腼腆': 2,
#          '腼腆的': 14,
#          '的90': 73,
#          '90后': 237,
#          '后青年': 23,
#          '青年刘青': 2,
#          '刘青介绍': 2,
#          '介绍6': 10,
#          '月16': 4316,
#          '16日': 4342,
#          '日早上': 85,
#          '早上7': 33,
#          '7时': 200,
#          '时36': 6,
#          '36分': 13,
#          '分他': 16,
#          '他正在': 56,
#          '正在环城': 2,
#          '环城南路': 4,
#          '南路附近': 3,
#          '附近值勤': 2,
#          '值勤接到': 2,
#          '接到中队': 2,
#          '中队关于': 2,
#          '关于一位': 2,
#          '一位女子': 5,
#          '女子裸身': 2,
#          '裸身进入': 2,
#          '进入机动车': 2,
#          '机动车可能': 2,
#          '可能有': 139,
#          '有危险': 23,
#          '危险的': 157,
#          '的警情': 5,
#          '警情随后': 2,
#          '随后骑着': 2,
#          '骑着小': 4,
#          '小铁骑': 4,
#          '铁骑开始': 2,
#          '开始沿路': 2,
#          '沿路寻找': 2,
#          '寻找大概': 2,
#          '大概花': 3,
#          '花了': 182,
#          '了十多分钟': 4,
#          '十多分钟在': 2,
#          '南坪大道': 2,
#          '大道坂田': 2,
#          '坂田出口': 2,
#          '出口往': 2,
#          '往龙岗': 2,
#          '龙岗方向': 2,
#          '方向的': 129,
#          '的逆行': 3,
#          '逆行辅道': 2,
#          '辅道上': 2,
#          '上发现': 54,
#          '发现该': 72,
#          '该女子': 46,
#          '女子女子': 7,
#          '女子身上': 4,
#          '身上一丝不挂': 2,
#          '一丝不挂地逆': 2,
#          '地逆车流': 2,
#          '车流而行': 2,
#          '而行时': 3,
#          '时走时': 2,
#          '走时停': 2,
#          '停时': 2,
#          '时坐': 4,
#          '坐时': 3,
#          '时躺': 2,
#          '躺险象环生': 2,
#          '险象环生刘青停': 2,
#          '刘青停好': 2,
#          '好小': 8,
#          '铁骑和': 2,
#          '和另外': 44,
#          '另外一名': 39,
#          '一名巡防': 2,
#          '巡防员': 6,
#          '员追': 2,
#          '追了': 8,
#          '了上去': 13,
#          '上去发现': 2,
#          '发现女子': 4,
#          '女子的': 51,
#          '的情绪': 154,
#          '情绪很': 5,
#          '很低落': 4,
#          '低落话': 2,
#          '话不': 13,
#          '不多': 239,
#          '多刘青': 2,
#          '刘青尝试': 2,
#          '尝试和': 12,
#          '和女子': 29,
#          '女子交流': 2,
#          '交流劝说': 2,
#          '劝说女子': 2,
#          '女子离开': 2,
#          '离开可': 2,
#          '可女子': 2,
#          '女子并': 12,
#          '并不': 1915,
#          '不愿意': 262,
#          '愿意接受': 30,
#          '接受继续': 2,
#          '继续缓慢': 3,
#          '缓慢地往': 2,
#          '地往南坪': 2,
#          '南坪快速路': 4,
#          '快速路的': 5,
#          '的主干道': 9,
#          '主干道上': 5,
#          '上走': 46,
#          '走去': 19,
#          '去此时': 2,
#          '此时路边': 2,
#          '路边上': 3,
#          '上已经': 59,
#          '已经聚集': 5,
#          '聚集了': 100,
#          '了很': 223,
#          '很市民': 2,
#          '市民围观': 4,
#          '围观为了': 2,
#          '为了不': 65,
#          '不刺激': 3,
#          '刺激女子': 2,
#          '情绪刘青': 2,
#          '刘青和': 4,
#          '和巡防': 5,
#          '员一边': 2,
#          '一边盯': 3,
#          '盯着': 88,
#          '着女子': 3,
#          '女子一边': 2,
#          '一边驱赶': 2,
#          '驱赶着': 2,
#          '着围观': 2,
#          '围观的': 21,
#          '的群众': 179,
#          '群众现场': 3,
#          '现场还原': 3,
#          '还原从': 2,
#          '从警方': 13,
#          '警方提供': 19,
#          '提供的': 846,
#          '的一份': 349,
#          '一份视频': 2,
#          '视频了解': 5,
#          '了解到': 1851,
#          '到16': 21,
#          '时25': 22,
#          '25分': 33,
#          '分女子': 2,
#          '女子出现': 4,
#          '出现在': 747,
#          '在坂雪岗': 2,
#          '坂雪岗大道': 4,
#          '大道与': 5,
#          '与环城': 2,
#          '南路的': 7,
#          '的监控': 64,
#          '监控视频': 55,
#          '视频中': 199,
#          '中此时': 4,
#          '此时女子': 2,
#          '女子还': 5,
#          '还穿着': 9,
#          '穿着白色': 4,
#          '白色的': 66,
#          '的内裤': 6,
#          '内裤正': 2,
#          '正沿着': 16,
#          '沿着坂雪岗': 2,
#          '大道往': 2,
#          '往南坪': 2,
#          '快速的': 59,
#          '的方向': 457,
#          '方向缓慢': 3,
#          '缓慢地': 10,
#          '地走': 56,
#          '走着': 17,
#          '着当时': 3,
#          '当时正值': 17,
#          '正值上班': 5,
#          '上班高峰期': 6,
#          '高峰期十字路口': 2,
#          '十字路口的': 7,
#          '的车流': 13,
#          '车流已经': 4,
#          '已经排起': 2,
#          '排起了': 31,
#          '了长队': 29,
#          '长队当': 2,
#          '当女子': 6,
#          '出现时': 36,
#          '时路上': 4,
#          '路上的': 143,
#          '的市民': 243,
#          '市民纷纷': 16,
#          '纷纷驻足': 9,
#          '驻足观望': 2,
#          '观望不少': 2,
#          '不少车辆': 5,
#          '车辆也': 12,
#          '也放慢': 2,
#          '放慢了': 8,
#          '了速度': 8,
#          '速度但': 3,
#          '但女子': 4,
#          '不为': 88,
#          '为市民': 90,
#          '市民观望': 2,
#          '观望停下': 2,
#          '停下脚步': 19,
#          '脚步依然': 2,
#          '依然缓慢': 5,
#          '缓慢走': 2,
#          '着当': 4,
#          '女子行进': 2,
#          '行进到': 3,
#          '到十字路口': 4,
#          '十字路口中间': 2,
#          '中间时': 3,
#          '时一辆': 14,
#          '一辆大': 10,
#          '大货车': 53,
#          '货车挡住': 2,
#          '挡住了': 17,
#          '了镜头': 4,
#          '镜头但是': 2,
#          '但是当': 18,
#          '女子再次出现': 2,
#          '再次出现镜头': 2,
#          '镜头时': 2,
#          '时可以': 60,
#          '可以发现': 63,
#          '女子已经': 3,
#          '已经没': 10,
#          '没穿': 11,
#          '穿内裤': 2,
#          '内裤了': 2,
#          '了全身': 2,
#          '全身裸露': 2,
#          '裸露继续': 2,
#          '继续朝着': 5,
#          '朝着南坪': 2,
#          '快速方向': 2,
#          '方向走': 15,
#          '去记者': 2,
#          '记者发现': 129,
#          '发现视频': 2,
#          '中女子': 5,
#          '女子周围': 2,
#          '周围并': 3,
#          '并没有': 1120,
#          '没有人': 135,
#          '人尾随': 2,
#          '尾随或者': 2,
#          '或者上前': 2,
#          '上前劝止': 2,
#          '劝止的': 2,
#          '市民一': 3,
#          '一大清早': 2,
#          '大清早路上': 2,
#          '路上看到': 8,
#          '看到这样': 19,
#          '这样的': 2719,
#          '的情况': 2894,
#          '情况恐怕': 2,
#          '恐怕大家': 3,
#          '大家都': 434,
#          '都没': 148,
#          '没办法': 98,
#          '办法淡定': 2,
#          '淡定面对': 2,
#          '面对这一': 22,
#          '这一情况': 38,
#          '情况刘青': 2,
#          '刘青表示': 2,
#          '表示一': 6,
#          '一开始': 361,
#          '开始根本': 2,
#          '根本不敢': 8,
#          '不敢看': 5,
#          '看她': 54,
#          '她心里': 12,
#          '心里挺': 12,
#          '挺别扭': 2,
#          '别扭感觉': 2,
#          '感觉很': 80,
#          '很尴尬': 10,
#          '尴尬但': 4,
#          '但当': 68,
#          '当刘青': 2,
#          '刘青跟随': 2,
#          '跟随女子': 2,
#          '女子上': 2,
#          '上了': 718,
#          '了南坪': 2,
#          '快速路主干道': 2,
#          '主干道时': 2,
#          '时女子': 2,
#          '女子作出': 2,
#          '作出了': 384,
#          '了让': 67,
#          '让人': 1020,
#          '人意想不到': 4,
#          '意想不到的': 45,
#          '的举动': 127,
#          '举动她': 3,
#          '她突然': 13,
#          '突然靠近': 2,
#          '靠近护栏': 2,
#          '护栏要': 2,
#          '要从': 210,
#          '从上面': 3,
#          '上面跳下去': 2,
#          '跳下去刘青': 2,
#          '刘青赶忙': 2,
#          '赶忙冲上去': 2,
#          '冲上去拉住': 2,
#          '拉住了': 2,
#          '了女子': 34,
#          '的手': 181,
#          '手将': 8,
#          '将其': 751,
#          '其控制': 17,
#          '控制住': 39,
#          '住并': 7,
#          '并远离': 5,
#          '远离护栏': 2,
#          '护栏碍于': 2,
#          '碍于女子': 2,
#          '女子没有': 2,
#          '没有穿衣服': 2,
#          '穿衣服刘青递': 2,
#          '刘青递上': 2,
#          '上衣服': 7,
#          '衣服女子': 2,
#          '女子没': 5,
#          '没接受': 2,
#          '接受还': 2,
#          '还把': 87,
#          '把衣服': 8,
#          '衣服扔': 2,
#          '扔到': 32,
#          '到排水沟': 2,
#          '排水沟里': 2,
#          '里继续': 3,
#          '继续往前走': 4,
#          '往前走没': 2,
#          '办法刘青': 2,
#          '刘青只能': 2,
#          '只能紧紧': 2,
#          '紧紧拉': 2,
#          '拉着': 22,
#          '着她': 61,
#          '她的': 1447,
#          '的一只': 211,
#          '一只手': 13,
#          '手跟': 2,
#          '跟在': 35,
#          '在后面': 46,
#          '后面刘青': 2,
#          '刘青一路上': 2,
#          '一路上耐心': 2,
#          '耐心地': 29,
#          '地开导': 2,
#          '开导安慰': 2,
#          '安慰她': 11,
#          '她但': 6,
#          '但只': 18,
#          '只听到': 5,
#          '听到她': 4,
#          '她不断': 4,
#          '不断地': 113,
#          '地重复': 9,
#          '重复着': 14,
#          '着一句': 5,
#          '一句话': 246,
#          '话要是': 2,
#          '要是你': 8,
#          '你也': 51,
#          '也遭遇': 24,
#          '遭遇我': 4,
#          '我的': 2359,
#          '的事': 790,
#          '事你': 13,
#          '也会': 1312,
#          '会这样': 26,
#          '的期间': 6,
#          '期间她': 30,
#          '她还': 212,
#          '还不时': 16,
#          '不时试图': 2,
#          '试图挣脱': 5,
#          '挣脱刘青': 2,
#          '刘青的': 4,
#          '的手要': 4,
#          '手要冲向': 2,
#          '冲向护栏': 2,
#          '护栏往下跳': 2,
#          '往下跳就': 2,
#          '就这样': 180,
#          '这样我': 19,
#          '我被': 28,
#          '被牵': 3,
#          '牵着': 24,
#          '着走': 15,
#          '走了': 273,
#          '了大概': 13,
#          '大概十多分钟': 2,
#          '十多分钟天': 2,
#          '天突然': 2,
#          '突然下起': 2,
#          '下起了': 3,
#          '了大暴雨': 2,
#          '大暴雨雨大': 2,
#          '雨大的': 2,
#          '的连': 15,
#          '连眼睛': 2,
#          '眼睛都': 10,
#          '都睁不开': 2,
#          '睁不开刘青': 2,
#          '刘青继续': 2,
#          '继续说': 9,
#          '说着': 71,
#          '着瞬间': 2,
#          '瞬间他们': 11,
#          '他们就': 119,
#          '就被': 255,
#          '被雨': 2,
#          '雨透': 2,
#          '透了': 8,
#          '了但': 284,
#          '女子依然': 2,
#          '依然不': 14,
#          '接受刘青': 2,
#          '的帮助': 398,
#          '帮助就': 6,
#          '就继续': 14,
#          '继续冒': 2,
#          '冒着': 113,
#          '着大雨': 10,
#          '大雨往前走': 2,
#          '往前走大概': 2,
#          '大概走': 3,
#          '了有': 151,
#          '有四十分钟': 2,
#          '四十分钟吧': 2,
#          '吧女子': 4,
#          '女子突然': 4,
#          '突然停下': 2,
#          '停下来说': 2,
#          '来说我': 16,
#          '我想': 492,
#          '想回家': 9,
#          '回家了': 26,
#          '了然后': 37,
#          '然后女子': 2,
#          '女子也': 7,
#          '也接受': 22,
#          '接受了': 325,
#          '了刘青': 2,
#          '刘青递过来': 2,
#          '递过来的': 10,
#          '的小': 827,
#          '小黄衣': 4,
#          '黄衣就': 2,
#          '就出现': 61,
#          '出现了': 957,
#          '了深圳': 31,
#          '深圳微博上': 2,
#          '微博上的': 7,
#          '的照片': 474,
#          '照片女子': 2,
#          '女子披着': 2,
#          '披着小': 2,
#          '黄衣刘青': 2,
#          '刘青小心翼翼': 2,
#          '小心翼翼地': 40,
#          '地在': 167,
#          '在旁边': 45,
#          '旁边走': 3,
#          '着的': 121,
#          '的场景': 231,
#          '场景从': 2,
#          '从南平': 2,
#          '南平快速': 2,
#          '快速下来': 2,
#          '下来后': 6,
#          '后刘青': 2,
#          '员将': 16,
#          '将女子': 12,
#          '女子带到': 2,
#          '带到了': 46,
#          '了附近': 25,
#          '附近的': 1207,
#          '的坂田': 2,
#          '坂田派出所': 2,
#          '派出所那': 2,
#          '那姑娘': 2,
#          '姑娘到底': 2,
#          '到底是': 118,
#          '是遭遇': 3,
#          '遭遇了': 104,
#          '了什么样': 8,
#          '什么样的': 328,
#          '的事情': 754,
#          '事情才': 2,
#          '才会': 353,
#          '会说': 82,
#          '说要是': 4,
#          '这样据': 2,
#          '据警方': 50,
#          '警方透露': 25,
#          '透露该': 18,
#          '女子姓': 4,
#          '姓陈': 3,
#          '陈系': 2,
#          '系湖北': 3,
#          '湖北人': 11,
#          '人今年': 38,
#          '今年44': 28,
#          '岁据': 8,
#          '据家属': 2,
#          '家属反映': 2,
#          '反映其有': 2,
#          '其有精神病': 2,
#          '精神病史': 5,
#          '史三天': 2,
#          '三天前': 11,
#          '前陈某': 2,
#          '陈某从': 4,
#          '从老家': 21,
#          '老家来': 3,
#          '来深圳': 11,
#          '网友但': 2,
#          '但约会': 2,
#          '约会受挫': 2,
#          '受挫导致': 2,
#          '导致情绪': 7,
#          '情绪异常': 3,
#          '异常女子': 2,
#          '女子遂': 2,
#          '遂产生': 2,
#          '产生轻生': 7,
#          '轻生念头': 8,
#          '念头目前': 2,
#          '目前陈某': 6,
#          '陈某已经': 3,
#          '已经被': 219,
#          '被送往': 182,
#          '送往深圳': 2,
#          '深圳某': 9,
#          '某精神病': 2,
#          '精神病医院': 8,
#          '医院进行': 72,
#          '进行治疗': 35,
#          '治疗大大': 1,
#          '大大君': 1,
#          '君只': 1,
#          '只希望': 21,
#          '希望姑娘': 1,
#          '姑娘能': 1,
#          '能早点': 7,
#          '早点康复': 3,
#          '康复其实': 1,
#          '其实真爱': 1,
#          '真爱的': 2,
#          '的到来': 429,
#          '到来并': 7,
#          '不存在': 326,
#          '存在年龄': 1,
#          '年龄的': 74,
#          '的限制': 197,
#          '限制你们': 1,
#          '你们说': 8,
#          '说呢': 5,
#          '呢因': 1,
#          '因善良': 1,
#          '善良的': 17,
#          '的原因': 886,
#          '原因一众': 1,
#          '一众网友': 2,
#          '网友纷纷': 45,
#          '纷纷为': 25,
#          '为交警': 7,
#          '交警暖': 2,
#          '暖男点': 2,
#          '男点ZAN': 2,
#          'ZAN弓常': 2,
#          '弓常yan': 2,
#          'yan桦': 2,
#          '桦就': 2,
#          '就想': 96,
#          '想问': 16,
#          '问这个': 8,
#          '这个小': 33,
#          '小哥哥': 9,
#          ...})

# %%
get_combination_prob('去','北京')
# Out:
# 1.8000459069772276e-06

# %%
get_combination_prob('波音','飞机')
# Out:
# 8.129239579897157e-07

# %%
get_combination_prob('草莓味','苹果')
# Out:
# 5.8065996999265405e-08

# %%
def get_pro_2_gram(w1, w2):
    return get_combination_prob(w1, w2) / get_prob(w1)

# %%
get_pro_2_gram('去', '沈阳')
# Out:
# 0.0006857770649650213

# %%
get_pro_2_gram('去', '北京')
# Out:
# 0.004251817802783131

# %%
from icecream import ic

# %%
def language_model_of_2_gram(sentence):
    sentence_probability = 1
    
    words = cut(sentence)
    print(words)
    for i, word in enumerate(words):
        if i == 0:
            prob = get_prob(word)
            #print(prob)
        else:
            previous = words[i-1]
            prob = get_pro_2_gram(previous,word)
            #print(prob)
        sentence_probability *= prob
        #print(i)
    return sentence_probability

# %%
language_model_of_2_gram('小明今天抽奖抽到一台苹果手机')
# Out:
# ['小明', '今天', '抽奖', '抽到', '一台', '苹果', '手机']
# 4.5133725473313174e-18

# %%
language_model_of_2_gram('小明今天抽奖抽到一台波音飞机')
# Out:
# ['小明', '今天', '抽奖', '抽到', '一台', '波音', '飞机']
# 3.9724842499924055e-18

# %% [markdown]
# # Review the problem using 2-gram

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "今晚我去吃火锅 今晚火锅去吃我",
    "洋葱奶昔来一杯 养乐多绿来一杯"
]

for s in need_compared:
    s1, s2 = s.split()
    p1, p2 = language_model_of_2_gram(s1), language_model_of_2_gram(s2)
    better = s1 if p1 >p2 else s2
    
    print('{} is more possible'.format(better))
    #print('-'*4 + ' {} with probility {}'.format(s1, p1))
    #print('-'*4 + ' {} with probility {}'.format(s2, p2))
# Out:
# ['今天', '晚上', '请', '你', '吃', '大餐', '，', '我们', '一起', '吃', '日料']
# ['明天', '晚上', '请', '你', '吃', '大餐', '，', '我们', '一起', '吃', '苹果']
# 今天晚上请你吃大餐，我们一起吃日料 is more possible
# ['真', '事', '一只', '好看', '的', '小猫']
# ['真是', '一只', '好看', '的', '小猫']
# 真是一只好看的小猫 is more possible
# ['今晚', '我', '去', '吃火锅']
# ['今晚', '火锅', '去', '吃', '我']
# 今晚我去吃火锅 is more possible
# ['洋葱', '奶昔', '来', '一杯']
# ['养乐多', '绿来', '一杯']
# 养乐多绿来一杯 is more possible

# %%
grammar = """
sentence => noun_phrase verb_phrase 
noun_phrase => Article Adj* noun belong 
belong => de property
de => 的
property => 眼睛 | 裙子 | 胳膊 | 尾巴
Adj* => null | Adj Adj*
verb_phrase => verb noun_phrase
Article =>  一个 | 这个
noun =>   女人 |  篮球 | 桌子 | 小猫
verb => 看着   |  坐在 |  听着 | 看见
Adj =>   蓝色的 |  好看的 | 小小的
"""

# %%
import random

# %%
def parse_grammar(grammar_str, sep='=>'):
    grammar = {}
    for line in grammar_str.split('\n'):
        line = line.strip()
        if not line:continue
            
        target, rules = line.split(sep)
        
        grammar[target.strip()] = [r.split() for r in rules.split('|')]
    
    return grammar

# %%
g = parse_grammar(grammar)

# %%
g
# Out:
# {'sentence': [['noun_phrase', 'verb_phrase']],
#  'noun_phrase': [['Article', 'Adj*', 'noun', 'belong']],
#  'belong': [['de', 'property']],
#  'de': [['的']],
#  'property': [['眼睛'], ['裙子'], ['胳膊'], ['尾巴']],
#  'Adj*': [['null'], ['Adj', 'Adj*']],
#  'verb_phrase': [['verb', 'noun_phrase']],
#  'Article': [['一个'], ['这个']],
#  'noun': [['女人'], ['篮球'], ['桌子'], ['小猫']],
#  'verb': [['看着'], ['坐在'], ['听着'], ['看见']],
#  'Adj': [['蓝色的'], ['好看的'], ['小小的']]}

# %%
def gene(grammar_parsed, target='sentence'):
    if target not in grammar_parsed: return target
    
    rule = random.choice(grammar_parsed[target])

    return ''.join(gene(grammar_parsed, target=r) for r in rule if r!='null')

# %%
random_generated = [gene(g) for _ in range(100)]

# %%
random_generated
# Out:
# ['一个桌子的裙子看见一个小猫的尾巴',
#  '这个桌子的尾巴看着一个蓝色的桌子的眼睛',
#  '一个小猫的尾巴听着这个女人的胳膊',
#  '一个好看的好看的好看的女人的裙子看见一个蓝色的小猫的眼睛',
#  '这个小小的篮球的眼睛坐在这个篮球的眼睛',
#  '这个蓝色的好看的好看的篮球的裙子坐在一个好看的好看的好看的小小的蓝色的小小的桌子的胳膊',
#  '这个好看的小猫的尾巴坐在这个好看的蓝色的篮球的尾巴',
#  '这个女人的胳膊看见一个女人的胳膊',
#  '一个桌子的尾巴坐在一个小小的小小的小小的小小的篮球的裙子',
#  '一个篮球的裙子看着这个小小的蓝色的女人的眼睛',
#  '一个小猫的眼睛看着一个小小的蓝色的女人的尾巴',
#  '这个好看的桌子的胳膊看着一个桌子的裙子',
#  '这个篮球的裙子听着这个好看的女人的裙子',
#  '这个小猫的尾巴看着这个好看的好看的好看的好看的好看的好看的小小的小小的好看的好看的好看的好看的小猫的尾巴',
#  '这个好看的篮球的尾巴看着这个好看的小猫的裙子',
#  '这个桌子的尾巴听着一个小猫的胳膊',
#  '这个好看的女人的胳膊看见这个桌子的眼睛',
#  '这个篮球的裙子看着这个篮球的眼睛',
#  '一个桌子的胳膊听着一个蓝色的小小的小猫的胳膊',
#  '一个小猫的尾巴看见这个小小的小小的小小的蓝色的小小的桌子的胳膊',
#  '这个小猫的胳膊听着这个桌子的裙子',
#  '这个小小的好看的篮球的裙子坐在一个好看的好看的小小的桌子的尾巴',
#  '一个蓝色的小猫的眼睛坐在一个篮球的裙子',
#  '这个篮球的尾巴听着这个小猫的胳膊',
#  '这个小小的小猫的裙子看见一个蓝色的小猫的尾巴',
#  '一个好看的桌子的眼睛听着一个小猫的胳膊',
#  '这个蓝色的蓝色的好看的篮球的胳膊看见一个蓝色的小猫的尾巴',
#  '这个蓝色的篮球的胳膊看着这个蓝色的女人的裙子',
#  '这个桌子的胳膊听着这个好看的好看的好看的小猫的裙子',
#  '一个女人的尾巴看着这个好看的桌子的胳膊',
#  '一个好看的蓝色的小小的篮球的尾巴坐在一个篮球的胳膊',
#  '一个女人的尾巴看着这个蓝色的小猫的尾巴',
#  '一个女人的尾巴看见一个小小的小小的小小的小小的好看的小小的桌子的裙子',
#  '一个好看的桌子的尾巴坐在一个蓝色的小小的桌子的胳膊',
#  '一个好看的蓝色的桌子的胳膊看着这个女人的胳膊',
#  '一个蓝色的蓝色的小小的好看的篮球的尾巴坐在一个篮球的胳膊',
#  '一个小小的桌子的眼睛听着一个篮球的胳膊',
#  '一个小小的女人的胳膊听着一个小猫的裙子',
#  '这个小小的女人的胳膊看着一个小小的好看的小猫的胳膊',
#  '一个蓝色的篮球的胳膊看着这个小小的好看的女人的眼睛',
#  '一个篮球的尾巴看见这个蓝色的蓝色的桌子的尾巴',
#  '一个好看的桌子的尾巴看见这个小猫的眼睛',
#  '这个小小的桌子的胳膊坐在一个好看的小猫的裙子',
#  '一个蓝色的篮球的裙子看着这个篮球的裙子',
#  '一个小小的桌子的胳膊听着这个桌子的尾巴',
#  '这个小小的篮球的裙子看见这个篮球的裙子',
#  '一个好看的蓝色的女人的眼睛看见这个好看的桌子的胳膊',
#  '这个小猫的裙子看见这个好看的蓝色的蓝色的篮球的裙子',
#  '这个桌子的眼睛看见这个小小的女人的尾巴',
#  '这个篮球的裙子听着这个好看的小猫的眼睛',
#  '一个桌子的眼睛听着一个好看的小猫的眼睛',
#  '一个篮球的裙子看见这个桌子的尾巴',
#  '一个篮球的尾巴听着这个桌子的眼睛',
#  '一个好看的小猫的胳膊看见这个篮球的尾巴',
#  '这个蓝色的小小的小小的篮球的胳膊坐在一个好看的女人的尾巴',
#  '这个小小的女人的裙子听着这个小小的蓝色的好看的小小的好看的蓝色的篮球的眼睛',
#  '一个女人的眼睛听着一个小小的好看的蓝色的小小的女人的胳膊',
#  '一个小小的蓝色的小猫的裙子看见这个桌子的眼睛',
#  '这个小猫的眼睛看见这个篮球的裙子',
#  '一个篮球的胳膊坐在一个蓝色的桌子的裙子',
#  '这个小小的桌子的胳膊听着这个好看的小猫的胳膊',
#  '这个小小的桌子的裙子看着这个篮球的尾巴',
#  '这个小小的小小的桌子的胳膊坐在这个蓝色的蓝色的蓝色的好看的小小的小猫的裙子',
#  '一个篮球的裙子看着这个女人的胳膊',
#  '一个小猫的胳膊坐在这个篮球的裙子',
#  '一个篮球的眼睛看着一个女人的眼睛',
#  '一个篮球的裙子坐在一个桌子的眼睛',
#  '一个蓝色的好看的好看的桌子的眼睛看着这个蓝色的篮球的眼睛',
#  '一个好看的小猫的胳膊看见一个好看的女人的裙子',
#  '一个好看的篮球的尾巴坐在一个桌子的胳膊',
#  '这个小小的小小的小猫的尾巴坐在一个小小的蓝色的蓝色的女人的眼睛',
#  '一个篮球的尾巴看见这个篮球的眼睛',
#  '一个小猫的胳膊看着这个小小的桌子的尾巴',
#  '这个蓝色的蓝色的桌子的胳膊看着一个篮球的胳膊',
#  '一个篮球的胳膊坐在一个桌子的裙子',
#  '一个小猫的裙子看见一个蓝色的篮球的裙子',
#  '这个小小的女人的胳膊看着一个小小的蓝色的好看的篮球的眼睛',
#  '一个好看的女人的眼睛看见这个女人的眼睛',
#  '一个小猫的胳膊看见这个蓝色的桌子的尾巴',
#  '一个蓝色的好看的小猫的尾巴看见一个好看的女人的尾巴',
#  '一个桌子的眼睛坐在这个桌子的胳膊',
#  '这个小小的女人的尾巴听着一个桌子的裙子',
#  '这个好看的桌子的裙子看着一个好看的女人的尾巴',
#  '一个篮球的裙子坐在一个蓝色的篮球的裙子',
#  '这个小猫的尾巴坐在这个小小的好看的蓝色的小小的小猫的胳膊',
#  '一个小小的女人的胳膊看着一个桌子的胳膊',
#  '一个好看的蓝色的篮球的尾巴看见一个小猫的裙子',
#  '这个小猫的尾巴听着这个女人的眼睛',
#  '这个桌子的裙子坐在一个好看的女人的眼睛',
#  '这个蓝色的蓝色的蓝色的篮球的尾巴看着一个篮球的胳膊',
#  '一个篮球的裙子听着一个篮球的胳膊',
#  '这个蓝色的好看的桌子的裙子听着一个小猫的眼睛',
#  '一个小猫的眼睛看见一个女人的胳膊',
#  '这个小小的篮球的胳膊坐在一个小猫的裙子',
#  '一个好看的篮球的眼睛听着这个小猫的尾巴',
#  '这个好看的小猫的眼睛坐在这个小猫的裙子',
#  '一个小小的篮球的眼睛坐在一个蓝色的小猫的眼睛',
#  '这个小猫的眼睛看见一个小小的小猫的尾巴',
#  '这个好看的小猫的眼睛听着这个篮球的眼睛',
#  '一个篮球的胳膊看着这个好看的小小的女人的胳膊']

# %%
s1 = {1,2,3}

# %%
s2 = {4,5,2}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5}

# %%
sorted(random_generated, key=language_model_of_2_gram, reverse=True)
# Out:
# ['一个', '桌子', '的', '裙子', '看见', '一个', '小猫', '的', '尾巴']
# ['这个', '桌子', '的', '尾巴', '看着', '一个', '蓝色', '的', '桌子', '的', '眼睛']
# ['一个', '小猫', '的', '尾巴', '听', '着', '这个', '女人', '的', '胳膊']
# ['一个', '好看', '的', '好看', '的', '好看', '的', '女人', '的', '裙子', '看见', '一个', '蓝色', '的', '小猫', '的', '眼睛']
# ['这个', '小小的', '篮球', '的', '眼睛', '坐在', '这个', '篮球', '的', '眼睛']
# ['这个', '蓝色', '的', '好看', '的', '好看', '的', '篮球', '的', '裙子', '坐在', '一个', '好看', '的', '好看', '的', '好看', '的', '小小的', '蓝色', '的', '小小的', '桌子', '的', '胳膊']
# ['这个', '好看', '的', '小猫', '的', '尾巴', '坐在', '这个', '好看', '的', '蓝色', '的', '篮球', '的', '尾巴']
# ['这个', '女人', '的', '胳膊', '看见', '一个', '女人', '的', '胳膊']
# ['一个', '桌子', '的', '尾巴', '坐在', '一个', '小小的', '小小的', '小小的', '小小的', '篮球', '的', '裙子']
# ['一个', '篮球', '的', '裙子', '看着', '这个', '小小的', '蓝色', '的', '女人', '的', '眼睛']
# ['一个', '小猫', '的', '眼睛', '看着', '一个', '小小的', '蓝色', '的', '女人', '的', '尾巴']
# ['这个', '好看', '的', '桌子', '的', '胳膊', '看着', '一个', '桌子', '的', '裙子']
# ['这个', '篮球', '的', '裙子', '听', '着', '这个', '好看', '的', '女人', '的', '裙子']
# ['这个', '小猫', '的', '尾巴', '看着', '这个', '好看', '的', '好看', '的', '好看', '的', '好看', '的', '好看', '的', '好看', '的', '小小的', '小小的', '好看', '的', '好看', '的', '好看', '的', '好看', '的', '小猫', '的', '尾巴']
# ['这个', '好看', '的', '篮球', '的', '尾巴', '看着', '这个', '好看', '的', '小猫', '的', '裙子']
# ['这个', '桌子', '的', '尾巴', '听', '着', '一个', '小猫', '的', '胳膊']
# ['这个', '好看', '的', '女人', '的', '胳膊', '看见', '这个', '桌子', '的', '眼睛']
# ['这个', '篮球', '的', '裙子', '看着', '这个', '篮球', '的', '眼睛']
# ['一个', '桌子', '的', '胳膊', '听', '着', '一个', '蓝色', '的', '小小的', '小猫', '的', '胳膊']
# ['一个', '小猫', '的', '尾巴', '看见', '这个', '小小的', '小小的', '小小的', '蓝色', '的', '小小的', '桌子', '的', '胳膊']
# ['这个', '小猫', '的', '胳膊', '听', '着', '这个', '桌子', '的', '裙子']
#  '一个桌子的裙子看见一个小猫的尾巴',
#  '一个篮球的裙子看见这个桌子的尾巴',
#  '这个桌子的眼睛看见这个小小的女人的尾巴',
#  '这个小猫的眼睛看见这个篮球的裙子',
#  '一个小小的女人的胳膊看着一个桌子的胳膊',
#  '一个小猫的尾巴听着这个女人的胳膊',
#  '一个小猫的胳膊看着这个小小的桌子的尾巴',
#  '一个篮球的胳膊坐在一个桌子的裙子',
#  '一个篮球的尾巴听着这个桌子的眼睛',
#  '这个桌子的尾巴听着一个小猫的胳膊',
#  '一个小猫的胳膊坐在这个篮球的裙子',
#  '这个小小的桌子的裙子看着这个篮球的尾巴',
#  '这个小猫的眼睛看见一个小小的小猫的尾巴',
#  '一个好看的女人的眼睛看见这个女人的眼睛',
#  '这个小猫的胳膊听着这个桌子的裙子',
#  '一个小小的女人的胳膊听着一个小猫的裙子',
#  '这个小小的篮球的眼睛坐在这个篮球的眼睛',
#  '这个篮球的尾巴听着这个小猫的胳膊',
#  '这个小小的篮球的胳膊坐在一个小猫的裙子',
#  '这个小小的篮球的裙子看见这个篮球的裙子',
#  '一个篮球的裙子听着一个篮球的胳膊',
#  '这个小小的女人的尾巴听着一个桌子的裙子',
#  '一个小小的桌子的胳膊听着这个桌子的尾巴',
#  '一个小小的桌子的眼睛听着一个篮球的胳膊',
#  '这个好看的女人的胳膊看见这个桌子的眼睛',
#  '这个桌子的裙子坐在一个好看的女人的眼睛',
#  '一个女人的尾巴看着这个好看的桌子的胳膊',
#  '一个女人的尾巴看着这个蓝色的小猫的尾巴',
#  '一个好看的桌子的尾巴看见这个小猫的眼睛',
#  '一个篮球的裙子看着这个小小的蓝色的女人的眼睛',
#  '一个小小的蓝色的小猫的裙子看见这个桌子的眼睛',
#  '一个好看的篮球的尾巴坐在一个桌子的胳膊',
#  '一个好看的小猫的胳膊看见这个篮球的尾巴',
#  '一个桌子的眼睛听着一个好看的小猫的眼睛',
#  '一个小猫的胳膊看见这个蓝色的桌子的尾巴',
#  '这个桌子的尾巴看着一个蓝色的桌子的眼睛',
#  '一个蓝色的篮球的裙子看着这个篮球的裙子',
#  '一个小猫的裙子看见一个蓝色的篮球的裙子',
#  '一个小小的篮球的眼睛坐在一个蓝色的小猫的眼睛',
#  '这个好看的小猫的眼睛坐在这个小猫的裙子',
#  '一个小猫的眼睛看着一个小小的蓝色的女人的尾巴',
#  '这个小小的桌子的胳膊坐在一个好看的小猫的裙子',
#  '这个好看的桌子的胳膊看着一个桌子的裙子',
#  '这个篮球的裙子听着这个好看的小猫的眼睛',
#  '一个蓝色的小猫的眼睛坐在一个篮球的裙子',
#  '这个好看的小猫的眼睛听着这个篮球的眼睛',
#  '一个篮球的胳膊坐在一个蓝色的桌子的裙子',
#  '一个好看的桌子的眼睛听着一个小猫的胳膊',
#  '一个篮球的裙子坐在一个蓝色的篮球的裙子',
#  '这个篮球的裙子听着这个好看的女人的裙子',
#  '这个小小的小猫的裙子看见一个蓝色的小猫的尾巴',
#  '这个小小的女人的胳膊看着一个小小的好看的小猫的胳膊',
